# %% [markdown]
# # Self-Reflective Micro-Agent Node

# %%
import os
import boto3
import json
import asyncio
from copy import deepcopy
from dotenv import load_dotenv
from neo4j import GraphDatabase, AsyncGraphDatabase
import aioboto3
import nest_asyncio
from typing import Literal, List, Any
from neo4j import AsyncGraphDatabase
from pydantic import BaseModel

load_dotenv()
nest_asyncio.apply()
model_name = "us.meta.llama3-2-11b-instruct-v1:0"
NEO4J_URI = os.getenv("NEO4J_URI", "")
NEO4J_USER = os.getenv("NEO4J_USER", "")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "")

# user_input = "stomach medicine sold by AS Watson"
# user_input = "medicine for stomach that's in promotion."
# user_input = "any promotion does vitasoy have now?"
user_input = "products by hola and in promotion"
# user_input = "promoted hair products"


# Create an async client for the Bedrock service
async def async_gen_chat(system: str, user: str) -> str:
    session = aioboto3.Session()
    async with session.client(
        "bedrock-runtime",
        aws_access_key_id=os.getenv("AWS_BEDROCK_SA_AK", ""),
        aws_secret_access_key=os.getenv("AWS_BEDROCK_SA_SK", ""),
        region_name=os.getenv("AWS_BEDROCK_META_REGION", "")
    ) as client:
        response = await client.converse(
            modelId=model_name,
            messages=[
                {
                    "role": "user",
                    "content": [{"text": user}]
                }
            ],
            system=[{"text": system}],
            inferenceConfig={
                "maxTokens": 1024,
                "temperature": 0,
                "stopSequences": []
            }
        )
        return response['output']['message']['content'][0]['text']

client = boto3.client(
    "bedrock-runtime",
    aws_access_key_id=os.getenv("AWS_BEDROCK_SA_AK",""),
    aws_secret_access_key=os.getenv("AWS_BEDROCK_SA_SK",""),
    region_name=os.getenv("AWS_BEDROCK_META_REGION","")
)

def gen_chat(system: str, user: str) -> str:
    response = client.converse(
        modelId=model_name,
        messages=[{
            "role": "user",
            "content": [{
                "text": user
            }]
        }],
        system=[{"text": system}],
        inferenceConfig={
            "maxTokens": 1024,
            "temperature": 0,
            "stopSequences": []
        }
    )
    return response['output']['message']['content'][0]['text']

def generate_embedding(input_texts, type: str = "search_document"):
    """
    Generate embeddings using Amazon Bedrock.
    """
    model_id = "cohere.embed-multilingual-v3"
    try:
        # Prepare the payload
        payload = {
            "texts": input_texts,
            "input_type": type,
            "truncate": "START"
        }
        
        # Invoke the model
        response = client.invoke_model(
            modelId=model_id,  # The model ID as configured in Bedrock
            contentType="application/json",  # Content type for the payload
            accept="*/*",  # Accept type for the response
            body=json.dumps(payload)  # Serialize the payload into JSON
        )
        
        # Parse the response
        # print(response['body'].read())
        response_body = json.loads(response['body'].read())
        embedding = response_body.get("embeddings", None)
        
        if embedding is None:
            raise ValueError("No embedding returned in the response.")
        
        return embedding
    
    except Exception as e:
        print(f"Error generating embedding: {e}")
        return None

class Neo4jHelper:

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self._driver.close()

    def create_node_if_not_exists(self, label, code, properties):
        query = f"""
        MERGE (n:{label} {{code: $code}})
        SET
        {', '.join([f'n.{key} = ${key}' for key in properties.keys()])}
        RETURN n
        """
        parameters = {"code": code, **properties}
        
        with self._driver.session() as session:
            result = session.run(query, parameters)
            return result.single()  # Return the first result (the created or matched node)
    
    def run_query(self, query):
        with self._driver.session() as session:
            result = session.run(query)
            return result
    
    def execute_query(self, query, **kwargs):
        records, summary, keys = self._driver.execute_query(
            query,
            **kwargs
        )
        return [record.data() for record in records]
class Neo4jHelper:

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self._driver.close()

    def create_node_if_not_exists(self, label, code, properties):
        query = f"""
        MERGE (n:{label} {{code: $code}})
        SET
        {', '.join([f'n.{key} = ${key}' for key in properties.keys()])}
        RETURN n
        """
        parameters = {"code": code, **properties}
        
        with self._driver.session() as session:
            result = session.run(query, parameters)
            return result.single()  # Return the first result (the created or matched node)
    
    def run_query(self, query):
        with self._driver.session() as session:
            result = session.run(query)
            return result
    
    def execute_query(self, query, **kwargs):
        records, summary, keys = self._driver.execute_query(
            query,
            **kwargs
        )
        return [record.data() for record in records]

class AsyncNeo4jHelper:

    def __init__(self, uri, user, password):
        # Use the async driver
        self._driver = AsyncGraphDatabase.driver(uri, auth=(user, password))

    async def close(self):
        # Close the driver asynchronously
        await self._driver.close()

    async def create_node_if_not_exists(self, label, code, properties):
        # Use an async session
        query = f"""
        MERGE (n:{label} {{code: $code}})
        SET
        {', '.join([f'n.{key} = ${key}' for key in properties.keys()])}
        RETURN n
        """
        parameters = {"code": code, **properties}
        
        async with self._driver.session() as session:
            # Run the query asynchronously
            result = await session.run(query, parameters)
            # Fetch the first result asynchronously
            return await result.single()  # Return the first result (the created or matched node)

    async def run_query(self, query):
        async with self._driver.session() as session:
            # Run the query asynchronously
            result = await session.run(query)
            return result  # Note: You'll need to process the result asynchronously

    async def execute_query(self, query, **kwargs):
        records, summary, keys = await self._driver.execute_query(
            query,
            **kwargs
        )
        # Process the records asynchronously
        return [record.data() for record in records]

# Connect to Neo4j
neo4j_helper = Neo4jHelper(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
async_neo4j_helper = AsyncNeo4jHelper(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)

# load prompts
with open("prompt_templates/node_reflection_no_traversal.txt", "r") as t: node_reflection_template = t.read()
with open("prompt_templates/starter.txt", "r") as t: starter_template = t.read()

# %%
def similar_node_by_vector(node_type: Literal["Product", "Brand", "Promotion", "Category"], query: str, threshold: float = 0.7, top_n: int = 10):
    template = """MATCH (p:{node_type}) WITH p,
    vector.similarity.cosine(p.embedding, $embedding) AS score
    WHERE score > {threshold} 
    RETURN labels(p) AS type, p.code AS code, p.title AS title, p.name AS name, p.description AS description, p.elabDescription AS elabDescription, score
    ORDER BY score DESC LIMIT {top_n};"""
    
    result = neo4j_helper.execute_query(
        query=template.format(node_type=node_type, threshold=threshold, top_n=top_n),
        embedding=generate_embedding([query], type="search_query")[0]
    )
    
    return result

# %%
# Kick Starter

starter = json.loads(gen_chat(system=starter_template, user=user_input))
user_input_embedding = generate_embedding([user_input], type="search_query")[0]
all_starts = []
for k, v in starter.items():
    all_possible_starts = similar_node_by_vector(node_type=k, query=", ".join(v))
    # sorted_starts = sorted(all_possible_starts, key=lambda x: x["score"], reverse=True)
    all_starts.extend(all_possible_starts)

# %%
class ReflectiveNode:
    
    class Reflection:
        related: bool
        explanation: str = ""
        relevance_score: float = 0
        def __init__(self, **kwargs):  self.__dict__.update(kwargs)
    
    class Relationship:
        direction: str
        relationship: str
        node: 'ReflectiveNode'
        
        def __init__(self, **kwargs): self.__dict__.update(kwargs)
        def to_partial_dict(self) -> dict:
            partial_dict = {
                "direction": self.direction,
                "relationship": self.relationship,
                "code": self.node.code,
                "name": self.node.name,
                "type": self.node.type
            }
            # return json.dumps(partial_prompt)
            return partial_dict
        
    code: str
    name: str
    user_query: str
    user_query_embedding: list[float]
    type: Literal["Product", "Category", "Brand", "Promotion"]
    description: str = ""
    relationships: List[Relationship] = []
    previous_node: 'ReflectiveNode' = None
    previous_traversal_reason: str = ""
    n_hop: int = 0
    
    def __init__(self, 
                 code, 
                 name,
                 type, 
                 user_query = "",
                 user_query_embedding = [],
                 description = "",
                 relationships = [],
                 previous_node = None,
                 previous_traversal_reason = "",
                 n_hop = 1,
                 **kwargs):
        self.code = str(code)
        self.name = name
        self.type = type
        self.user_query = user_query
        self.user_query_embedding = user_query_embedding
        self.description = description
        self.previous_node = previous_node
        self.previous_traversal_reason = previous_traversal_reason
        self.n_hop = n_hop
        if relationships: self.relationships = relationships
        self.__dict__.update(kwargs)
    
    def to_partial_dict(self) -> dict:
        partial_dict = {
            "code": self.code,
            "type": self.type,
            "name": self.name,
            "description": self.description
        }
        if self.type == "Product":
            partial_dict["countryOfOrigin"] = getattr(self, "countryOfOrigin", "N/A")
            partial_dict["stockLevelStatus"] = getattr(self, "countryOfOrigin", "N/A")
        return partial_dict
    
    def to_partial_prompt(self) -> str:
        return json.dumps(self.to_partial_dict(), indent=2)
    
    async def set_relationships(self):
        q_code = self.code if self.type == "Promotion" else f"\"{self.code}\""
        # this big query gets all its neighborhoods and filter out the top 5 of each type my similarity to the user's query
        q = f"""
        WITH {self.user_query_embedding} AS queryEmbedding  // Replace with the actual query embedding
        MATCH (n:{self.type} {{code: {q_code}}})
        OPTIONAL MATCH (l)-[r]-(n)
        WHERE l.embedding IS NOT NULL
        WITH l, r, n, vector.similarity.cosine(l.embedding, queryEmbedding) AS similarity
        ORDER BY similarity DESC
        WITH labels(l) AS nodeLabels, l, r, n, similarity
        UNWIND nodeLabels AS nodeLabel
        WITH nodeLabel, l, r, n, similarity
        ORDER BY similarity DESC  // Re-order based on similarity for each label
        WITH nodeLabel, collect({{
            nodeType: nodeLabel,
            code: l.code,
            name: l.name,
            title: l.title,
            description: l.description,
            elabDescription: l.elabDescription,
            countryOfOrigin: l.elabCountryOfOrigin,
            stockLevelStatus: l.stockLevelStatus,
            relationship: r,
            direction: CASE 
                WHEN (n)-[r]->(l) THEN 'OUTGOING' 
                WHEN (n)<-[r]-(l) THEN 'INCOMING' 
                ELSE 'UNDIRECTED' 
            END,
            similarity: similarity
        }}) AS collectedNodes
        WITH nodeLabel, collectedNodes[0..5] AS topNodes
        UNWIND topNodes AS node
        RETURN node.nodeType AS nodeType, node.code AS code, node.name AS name, node.title AS title, node.description AS description, 
            node.elabDescription AS elabDescription, node.countryOfOrigin AS countryOfOrigin, node.stockLevelStatus AS stockLevelStatus, 
            node.relationship AS relationship, node.direction AS direction, node.similarity AS similarity
        """
        db_results = await async_neo4j_helper.execute_query(q)
        self.relationships=[]
        for r in db_results:
            related_node = ReflectiveNode(
                code=r["code"],
                name=r["name"] if r["name"] else r["title"],
                type=r["nodeType"],
                description=r["elabDescription"] if r["elabDescription"] else r["description"],
                user_query=self.user_query,
                user_query_embedding=self.user_query_embedding,
                previous_node=self,
                n_hop=self.n_hop + 1
            )
            if r["countryOfOrigin"]: related_node.countryOfOrigin = r["countryOfOrigin"]
            if r["stockLevelStatus"]: related_node.stockLevelStatus = r["stockLevelStatus"]
            self.relationships.append(self.Relationship(
                direction = r["direction"],
                relationship = r["relationship"][1],
                node = related_node
            ))
            
    def match_node(self, type: str, code: str):
        for r in self.relationships:
            if getattr(r.node, 'type', "") == type and getattr(r.node, 'code', "") == code:
                return r.node
        return None
    
    async def reflect(self) -> Reflection:
        prompt = node_reflection_template
        prompt = prompt.replace("CURRENT_NODE", self.to_partial_prompt())
        prompt = prompt.replace("CURRENT_RELATIONSHIPS", json.dumps([r.to_partial_dict() for r in self.relationships], indent=2))
        gen_result = await async_gen_chat(system=prompt, user=self.user_query)
        try:
            gen_result_dict = json.loads(gen_result)
        except Exception as e:
            print(e)
            return self.Reflection(
                related=False,
                relevance_score=0,
                explanation=""
            )
            
        print(json.dumps(gen_result_dict, indent=2))
        if gen_result_dict["related"]:
            return self.Reflection(
                related=True,
                relevance_score=gen_result_dict["relevance_score"],
                explanation=gen_result_dict["explanation"]
            )
        else:
            return self.Reflection(
                related=False,
                relevance_score=gen_result_dict["relevance_score"],
                explanation=gen_result_dict["explanation"]
            )

# %%
related_nodes = []
nodes_to_analyze = [
    ReflectiveNode(
        code=item["code"],
        name=item["name"] if item["name"] else item["title"],
        type=item["type"][0],
        user_query=user_input,
        user_query_embedding=user_input_embedding,
        description=item["description"] if item["description"] else item["elabDescription"]
    ) for item in all_starts
]


async def analyze(node: ReflectiveNode):
    await node.set_relationships()
    reflection = await node.reflect()
    if reflection.related:
        node_dict = node.to_partial_dict()
        node_dict["relationships"] = [r.to_partial_dict() for r in node.relationships]
        related_nodes.append(
            {
                "node": node_dict,
                "explanation": reflection.explanation,
                "relevance_score": reflection.relevance_score
            }
        )
tasks = [analyze(n) for n in nodes_to_analyze]
node_analysis_result = await asyncio.gather(*tasks)
# Out:
# {
#   "related": true,
#   "relevance_score": 0.7,
#   "explanation": "The product 'Pien Tze Huang Gan Bao' is part of a promotion and has a name that is a product, which matches the user's query for products by hola and in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a product and has a promotion relationship with several promotions, which matches the user's query for products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.7,
#   "explanation": "The current node is related to a promotion and has a brand, which matches the user's query for products by a specific brand in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'sb_packset' is related to products, and the query contains keywords 'products by hola and in promotion', which indicates a strong relevance."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with other nodes, which matches the user's interest in products by Hola and in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'HALOCK' matches the query 'hola' and the neighbors are products, which matches the query 'products by'. Additionally, the neighbors have a 'SELLS' relationship, which implies they are on promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with a code that contains the word 'promotion'."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The product 'Tin Hee Tong Tin Hee Pills' is promoted by a category 'Buy 2 Get 1 Promotion' and also belongs to a category 'Fertility Supplements ' which is related to the user's query 'products by hola and in promotion'"
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a category related to products, which matches the user's query about products. Although the query mentions 'hola' and 'promotion', the category is still relevant as it contains products that could be on promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.5,
#   "explanation": "The current node is related to the user's query because it is promoted by a promotion related to a product, and the query contains keywords related to products."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'HOE HIN' matches the query term 'hola' and the query term 'promotion' is related to the relationship 'SELLS' which implies that the products are on sale."
# }
# {
#   "related": true,
#   "relevance_score": 0.7,
#   "explanation": "The product is promoted by '$1999-$250' and '$1488 Free Luggage' which matches the user's query 'products by hola and in promotion'"
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is related to products, and the query mentions products by Hola, but since the node is a category and has products by Durex, it's still relevant, but not as specific as the query."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and has two products related to it, which matches the user's query for products by Hola in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and has 4 related products, which matches the user's query for products by hola in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in a promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a brand named 'HOLA' and has outgoing relationships with products, which matches the user's query for products by HOLA. The relevance score is 0.8 because the query also mentions 'in promotion', but the provided data does not contain information about promotions."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a brand named &HONEY, which matches the query term 'hola'. Although the query term 'promotion' is not explicitly mentioned in the node's data, the node is related to products, which are often associated with promotions."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'agelessliving_digest' is related to products by Hola and in promotion, as it contains products like 'Nestle NESPRAY 800g' and 'INSTANT FULL CREAM MILK POWDER' which are likely to be in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is related to products by Hola and in promotion, as it contains products with 'Elseve Extraordinary Oil' and 'Japan Hot-selling Hair Oil' which are likely to be promoted products."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'agelessliving_eyes' is related to products by Hola and in promotion, as it is part of several products including 'Vita Green Fortified Natural Formula I See 40pcs' and 'YESNUTRI EYEBRIGHT & BILBERRY SU 60s' which are likely to be promoted by Hola."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.7,
#   "explanation": "The product 'CUPAL Angong Niuhuang Wan 1pc' is related to the query 'products by hola and in promotion' because it is promoted by a supplier coupon and it is a product from the brand 'CUPAL'."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The product 'TW Kinzan Kinmen Yi Tiao Gen Pth' is promoted by several offers, including 'BUY 2 GET 1 FREE', 'Over $300 Free GWP', and '$350 less $30', which matches the user's query for products in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'SALONPAS' is related to the user's query as it is a brand that sells products, and the query is looking for products by a brand and possibly in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'crest_toothstrips' is related to products, which matches the query 'products by hola and in promotion'. Although 'hola' is not present in the node's neighbors, the presence of 'products' is a strong match."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'DR. ORA' is related to the query 'products by hola and in promotion' because it sells products, but the relevance score is not 1 because the query does not mention 'DR. ORA' directly."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node is related to products, and the query mentions products by Hola, which is a brand, and in promotion, which is a common marketing strategy. Although the exact brand 'Hola' is not mentioned in the node's neighbors, the node is related to products, which is a key part of the query."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'sb_mex' is related to products by Hola and in promotion, as it is part of several products with the brand 'Men Expert' and 'Hydra Power Water Power' which might be on promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.5,
#   "explanation": "The current node 'STELLA' is a brand and one of its products 'CETIRIZINE STELLA TABLETS 10MG' is related to the query 'products by hola and in promotion'. Although 'hola' is not directly related to 'STELLA', the query is related to the product and the brand."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'sb_ha' is related to products by Hola and in promotion, as it contains products from the 'Hyaluronic Acid' category, which is likely to be a product line by Hola, and some of these products are in promotion."
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'AND' is related to products in promotion, as indicated by the neighbor 'UA-767S BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]'"
# }
# {
#   "related": true,
#   "relevance_score": 0.6,
#   "explanation": "The current node 'HIYA KIOGAN' is a brand and one of its products 'Excellent Pills Hiya Kiogan Gold 200 pills' is in the database, but the query is about 'hola' which is not present in the current node. However, the query is also about 'promotion' which is not present in the current node, but the product is present, so the relevance score is 0.6"
# }
# {
#   "related": true,
#   "relevance_score": 0.8,
#   "explanation": "The current node 'AHALO BUTTER' is related to the query 'products by hola and in promotion' because it is a brand and the query mentions a brand name 'hola'. Although the query mentions 'in promotion', the current node does not have any information about promotions, but it is still a relevant result."
# }

# %%
print(json.dumps(related_nodes, indent=2))
# Out:
# [
#   {
#     "node": {
#       "code": "BP_247314",
#       "type": "Product",
#       "name": "Pien Tze Huang Gan Bao",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "merrygiftmas22_healthp",
#           "name": "Selected Health products",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "printad_0617_1",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "midyearsale_2022_all",
#           "name": "MoneyBack Member purchase selected items upon $50 and enter promo code \u201chappy12\u201d get 12% off ",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "super_jetso_2022_3",
#           "name": "\u6fc0\u62b5\u8cb7",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_liver_daily_protection",
#           "name": "\u65e5\u5e38\u8b77\u809d",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134474",
#           "name": "LONG JIANG",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'Pien Tze Huang Gan Bao' is part of a promotion and has a name that is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "BP_228620",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "cvs22_adult",
#           "name": "Consumption Voucher Rewards - Adult Milk Powder",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050204",
#           "name": "Pain Patch",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134098",
#           "name": "LING NAM",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The current node is a product and has a promotion relationship with several promotions, which matches the user's query for products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_251730",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "sbd_10_2024_health",
#           "name": "Purchases selected Cordyceps/Chinese Medicine upon $699 will get 1pc of complimentary gift for free",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "summercombo_chinesemed",
#           "name": "Buy selected Chinese Medicine/Cordyceps items upon $699",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "141272",
#           "name": "KIN WO TONG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The current node is related to a promotion and has a brand, which matches the user's query for products by a specific brand in promotion.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "sb_packset",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_270618",
#           "name": "Men Expert Hydra Energetic Detox Foam + MA8 Set 100ml+50ml (Cleanser / Foam / Cream / Moisturizing / Detoxify)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_813233",
#           "name": "Revitalift 12345 Packset",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_238875",
#           "name": "Revitalift Essence Water + Day cream set (Anti-aging) 130ml+50ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_802653",
#           "name": "Beauty Tube + MUR Packset",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814867",
#           "name": "Men Expert Hydra Power Water Power Milk Twinset Moisturizer  50ml + 50ml (Moisturizer / Cream / Moisturizing)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_packset' is related to products, and the query contains keywords 'products by hola and in promotion', which indicates a strong relevance.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_292437",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_tourist",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134098",
#           "name": "LING NAM",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with other nodes, which matches the user's interest in products by Hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "108031",
#       "type": "Brand",
#       "name": "HALOCK",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_810769",
#           "name": "HALOCK S.O.S Pore Refining Watery Mask 8pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_809607",
#           "name": "HALOCK S.O.S Aqua Recharging Mask 8pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_812120",
#           "name": "S.O.S Brightening Watery Mask 8 pcs",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HALOCK' matches the query 'hola' and the neighbors are products, which matches the query 'products by'. Additionally, the neighbors have a 'SELLS' relationship, which implies they are on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_298356",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050206",
#           "name": "Medicated Oil",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "114763",
#           "name": "NAU LUNG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with a code that contains the word 'promotion'.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_298442",
#       "type": "Product",
#       "name": "Tin Hee Tong Tin Hee Pills",
#       "description": null,
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "win_back_july_all_items",
#           "name": "Free H&B selected item upon $299 purchase on selected Health Food/Vitamin/Adult Nutrition/Medicine & Eye Care products",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "win_back_july_medicine",
#           "name": "\u6307\u5b9a\u4e2d\u897f\u85e5\u53ca\u773c\u90e8\u8b77\u7406\u7522\u54c1\u6eff$299\u9001H&B\u6307\u5b9a\u7522\u54c1",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "buy2get1_product",
#           "name": "Buy 2 Get 1 Promotion",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "040505",
#           "name": "Fertility Supplements ",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "hh_0309_24",
#           "name": "Purchase selected items upon $188 and enter promo code \u201cMB188\u201d to enjoy 12% off (9-10/3)",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "136092",
#           "name": "TIN HEE TONG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The product 'Tin Hee Tong Tin Hee Pills' is promoted by a category 'Buy 2 Get 1 Promotion' and also belongs to a category 'Fertility Supplements ' which is related to the user's query 'products by hola and in promotion'",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "laurier_brandcat",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_477813",
#           "name": "Laurier F Pantyliner Scented 54's",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_477812",
#           "name": "Laurier F Pantyliner Non-Scented 54's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a category related to products, which matches the user's query about products. Although the query mentions 'hola' and 'promotion', the category is still relevant as it contains products that could be on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_294253",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_tourist",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050105",
#           "name": "\u80a0\u80c3",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "125324",
#           "name": "YA-HOM POWDER",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The current node is related to the user's query because it is promoted by a promotion related to a product, and the query contains keywords related to products.",
#     "relevance_score": 0.5
#   },
#   {
#     "node": {
#       "code": "133002",
#       "type": "Brand",
#       "name": "HOE HIN",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_108925",
#           "name": "HOE HIN PAK FAH YEOW #1 20ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_111855",
#           "name": "HOE HIN PAK FAH YEOW #2 10ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_106749",
#           "name": "HOE HIN PAK FAH YEOW #3 5ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816441",
#           "name": "HOE HIN PAK FAH YEOW 50ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HOE HIN' matches the query term 'hola' and the query term 'promotion' is related to the relationship 'SELLS' which implies that the products are on sale.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_155179",
#       "type": "Product",
#       "name": "TONG REN TANG YIN CHIAO CHIEH TU PIEN",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050205",
#           "name": "Cough Cold & Flu",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "120483",
#           "name": "TONG REN TANG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The product is promoted by '$1999-$250' and '$1488 Free Luggage' which matches the user's query 'products by hola and in promotion'",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "durextest",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814850",
#           "name": "Durex Real Feel Silicone Based Lube 50ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814848",
#           "name": "Durex Warming Lube 100ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products, and the query mentions products by Hola, but since the node is a category and has products by Durex, it's still relevant, but not as specific as the query.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148150",
#       "type": "Promotion",
#       "name": "Buy 2pcs Get Free",
#       "description": "Buy 2 Unit A Get B Free Buy 2pcs Get Fre",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_818414",
#           "name": "AHC Colla-Juvenation Lift 4 Serum 40ML",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_818413",
#           "name": "AHC Colla-Juvenation Lift 4 Eye Cream 30ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and has two products related to it, which matches the user's query for products by Hola in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149085",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_290136",
#           "name": "Nose Hygiene & Comfort 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_242136",
#           "name": "Nasal Hygiene Baby 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_215460",
#           "name": "Blocked Nose 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_259290",
#           "name": "Blocked Nose Baby 50ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and has 4 related products, which matches the user's query for products by hola in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "147381",
#       "type": "Promotion",
#       "name": "2 Or More 10%Off",
#       "description": "2 Or More 10%Off 2 Or More 10% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_214452",
#           "name": "Joint Easy 60's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in a promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "146281",
#       "type": "Brand",
#       "name": "HOLA",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817714",
#           "name": "HOLA PORTABLE MAKE UP BOX(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817711",
#           "name": "HOLA  ROCKING RATTLES 10 PCS(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817727",
#           "name": "HOLA PEACOCK(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817734",
#           "name": "HOLA POCKET DINOSAUR(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817718",
#           "name": "HOLA HONEYCOMB TEETHING TOY(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a brand named 'HOLA' and has outgoing relationships with products, which matches the user's query for products by HOLA. The relevance score is 0.8 because the query also mentions 'in promotion', but the provided data does not contain information about promotions.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148532",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_292956",
#           "name": "YiTiao Gen Essence Cream 30g",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148807",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817345",
#           "name": "CORDYCEPS HAIR REJUVENATION 60S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "137649",
#       "type": "Promotion",
#       "name": "2 Or More 10%Off",
#       "description": "2 Or More 10%Off 2 Or More 10% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_242535",
#           "name": "Rauma HP Cream",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149390",
#       "type": "Promotion",
#       "name": "Add $1 Get 1",
#       "description": "2nd Item At $1 Add $1 Get 1",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_815805",
#           "name": "PROCALUN DEEP REPAIRING & MOISTURIZING MASK",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "127077",
#       "type": "Brand",
#       "name": "&HONEY",
#       "description": "&HONEY",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817214",
#           "name": "&HONEY FLEUR KINMOKUSEI & MIMOSA MOIST HAIR OIL 100ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817215",
#           "name": "&HONEY FLEUR MIMOSA MOIST TREATMENT 445G",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817216",
#           "name": "&HONEY FLEUR KINMOKUSEI MOIST SHAMPOO 440ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817211",
#           "name": "&HONEY PIXIE MOIST SILKY TREATMENT 445G",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817210",
#           "name": "&HONEY PIXIE MOIST SILKY HAIR OIL 100ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a brand named &HONEY, which matches the query term 'hola'. Although the query term 'promotion' is not explicitly mentioned in the node's data, the node is related to products, which are often associated with promotions.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "agelessliving_digest",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_100191",
#           "name": "Nestle NESPRAY 800g",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_299203",
#           "name": "BioGaia Reuteri Gastrus Probiotic Chewable Tablets",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_100192",
#           "name": "INSTANT FULL CREAM MILK POWDER",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_264304",
#           "name": "Probiotics+ Daily Health",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_257101",
#           "name": "Advanced Probiotics",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'agelessliving_digest' is related to products by Hola and in promotion, as it contains products like 'Nestle NESPRAY 800g' and 'INSTANT FULL CREAM MILK POWDER' which are likely to be in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "sb_hairoil",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_242012",
#           "name": "Elseve Extraordinary Oil Infusion Oil Rose 100ml (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_397304",
#           "name": "Elseve Extraordinary Oil Airy Silk Moisturized & Smooth Hair 100ml (Gold) (Japan Hot-selling Hair OIl)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814050",
#           "name": "Elseve Extraordinary Oil Airy Silk Moisturized & Smooth Hair Refill (Gold) 90ml (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_269617",
#           "name": "Elseve Extraordinary Oil Extra Rich Deeply Moisturized & Damage Care 100ml (Brown) (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_282960",
#           "name": "Elseve Extraordinary Oil Extra Brilliance Moisturized Dazzling Shiny Hair 100ml (Rose) (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products by Hola and in promotion, as it contains products with 'Elseve Extraordinary Oil' and 'Japan Hot-selling Hair Oil' which are likely to be promoted products.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149389",
#       "type": "Promotion",
#       "name": "Add $1 Get 1",
#       "description": "2nd Item At $1 Add $1 Get 1",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_815253",
#           "name": "PROCALUN INTENSIVE MOIST & REPAIRING LIP BALM",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "agelessliving_eyes",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_237360",
#           "name": "Vita Green Fortified Natural Formula I See 40pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_807663",
#           "name": "YESNUTRI EYEBRIGHT & BILBERRY SU 60s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_805396",
#           "name": "LUTIGOLD EXTRA 20MG 30S",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_295233",
#           "name": "Macu-Vision Plus",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_224169",
#           "name": "Bilberry Extract",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'agelessliving_eyes' is related to products by Hola and in promotion, as it is part of several products including 'Vita Green Fortified Natural Formula I See 40pcs' and 'YESNUTRI EYEBRIGHT & BILBERRY SU 60s' which are likely to be promoted by Hola.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148806",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817344",
#           "name": "CORDYCEPS HAIR DARKENING 60S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148805",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817341",
#           "name": "TIBETAN WILD CORDYCEPS 60",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_816782",
#       "type": "Product",
#       "name": "CUPAL Angong Niuhuang Wan 1pc",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "flash_deal_1106",
#           "name": "Offer only valid on 6 Nov 2024, MoneyBack Member purchase selected items upon $888 and enter promo code \u3010WTC888\u3011 to save $130 and purchase selected items upon $1,299 and enter promo code \u3010WTC1299\u3011 to save $200",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "hh_1109",
#           "name": "\u53ea\u96509-10/11\u9650\u6642\u9a5a\u559c, \u8cb7\u6eff$188\uff0c\u8f38\u5165\u512a\u60e0\u78bc[MB188]\u5373\u4eab\u5168\u55ae88\u6298",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "040301",
#           "name": "Cardiovascular",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "148407",
#           "name": "Buy 2 at 20% off",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149302",
#           "name": "Supplier Coupon",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "131484",
#           "name": "CUPAL",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'CUPAL Angong Niuhuang Wan 1pc' is related to the query 'products by hola and in promotion' because it is promoted by a supplier coupon and it is a product from the brand 'CUPAL'.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "BP_268043",
#       "type": "Product",
#       "name": "TW Kinzan Kinmen Yi Tiao Gen Pth",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_products_offer",
#           "name": "\u5168\u7dda\u5065\u5eb7\u7522\u54c188\u6298",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "vita_joint_cross_promotion",
#           "name": "\u8cb7\u7cbe\u9078\u7dad\u7279\u5065\u9748\u5916\u7528\u9aa8\u9abc\u53ca\u95dc\u7bc0\u7522\u54c12\u4ef6\u9001\u6d3b\u95dc\u7d20\u7279\u5f37\u7279\u654810\u7c92\u88dd",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "148447",
#           "name": "BUY 2 GET 1 FREE",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "141298",
#           "name": "KINZAN",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'TW Kinzan Kinmen Yi Tiao Gen Pth' is promoted by several offers, including 'BUY 2 GET 1 FREE', 'Over $300 Free GWP', and '$350 less $30', which matches the user's query for products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "119102",
#       "type": "Brand",
#       "name": "SALONPAS",
#       "description": "SALONPAS",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_201963",
#           "name": "Salonpas Advanced Formula Patches 4's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_160495",
#           "name": "Salonpas Advanced Formula Patches 10's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_237951",
#           "name": "SALONPAS ADVANCED PLASTER 20S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_298406",
#           "name": "Salonsip Hot Patch 12's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_152100",
#           "name": "SALONSIP GEL-PATCH 12's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'SALONPAS' is related to the user's query as it is a brand that sells products, and the query is looking for products by a brand and possibly in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "crest_toothstrips",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_253070",
#           "name": "Crest Whitestrips Gentle Routine",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_171580",
#           "name": "3D White Strips Professional Effect 20 Treatments",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'crest_toothstrips' is related to products, which matches the query 'products by hola and in promotion'. Although 'hola' is not present in the node's neighbors, the presence of 'products' is a strong match.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "135714",
#       "type": "Brand",
#       "name": "DR. ORA",
#       "description": "DR. ORA",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816633",
#           "name": "DR ORA CRYSTAL LUXE COLLAGEN 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816635",
#           "name": "DR ORA LACTOLEAN PROBIOTICS 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816636",
#           "name": "DR ORA BLOCK IT! CARB BLOCKER 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816634",
#           "name": "DR ORA AURA WHITE ULTRA 15S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'DR. ORA' is related to the query 'products by hola and in promotion' because it sells products, but the relevance score is not 1 because the query does not mention 'DR. ORA' directly.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "fourhypers_agelessliving",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_277022",
#           "name": "King Alaska Deep Sea Fish Oil Softgel 200s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_282456",
#           "name": "King Alaska Lecithin Softgels 200s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_248504",
#           "name": "GS Go Out Tea 30s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_804199",
#           "name": "Omega-3 mini EPA/DHA",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_279469",
#           "name": "Rattle Mate Tea 30 tea bags",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products, and the query mentions products by Hola, which is a brand, and in promotion, which is a common marketing strategy. Although the exact brand 'Hola' is not mentioned in the node's neighbors, the node is related to products, which is a key part of the query.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "sb_mex",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_273885",
#           "name": "HYDRA POWER WATER POWER LOTION 120ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_270618",
#           "name": "Men Expert Hydra Energetic Detox Foam + MA8 Set 100ml+50ml (Cleanser / Foam / Cream / Moisturizing / Detoxify)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_249379",
#           "name": "Men Expert Hydra Energetic Multi-Action 8 Moisturizer 50ml (Moisturizing / Cream/ Detoxify / Energize)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_249378",
#           "name": "Hydra Energetic Detoxifying Cleansing Foam 100ML",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_273886",
#           "name": "Men Expert Hydra Power Water Power Milk Moisturizer  50ml (Moisturizer / Cream / Moisturizing)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_mex' is related to products by Hola and in promotion, as it is part of several products with the brand 'Men Expert' and 'Hydra Power Water Power' which might be on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "119748",
#       "type": "Brand",
#       "name": "STELLA",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_809138",
#           "name": "CETIRIZINE STELLA TABLETS 10MG",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'STELLA' is a brand and one of its products 'CETIRIZINE STELLA TABLETS 10MG' is related to the query 'products by hola and in promotion'. Although 'hola' is not directly related to 'STELLA', the query is related to the product and the brand.",
#     "relevance_score": 0.5
#   },
#   {
#     "node": {
#       "code": "sb_ha",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_813644",
#           "name": "Hyaluronic Acid 8s Wonder Water 400ml Airy Silky Liquid Hair Mask",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810148",
#           "name": "Hyaluronic Acid 8s Wonder Water 200ml Airy Silky Liquid Hair Mask",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810149",
#           "name": "Hyaluronic Acid Water Plump Conditioner 440ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810150",
#           "name": "Hyaluronic Acid Water Plump Shampoo 440ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_ha' is related to products by Hola and in promotion, as it contains products from the 'Hyaluronic Acid' category, which is likely to be a product line by Hola, and some of these products are in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "101907",
#       "type": "Brand",
#       "name": "AND",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_815836",
#           "name": "UA-767S BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_815837",
#           "name": "UA-654MR BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_809548",
#           "name": "AND ARM TYPE BPM - UA654MR",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'AND' is related to products in promotion, as indicated by the neighbor 'UA-767S BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]'",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "133353",
#       "type": "Brand",
#       "name": "HIYA KIOGAN",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_201172",
#           "name": "Excellent Pills Hiya Kiogan Gold 200 pills",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HIYA KIOGAN' is a brand and one of its products 'Excellent Pills Hiya Kiogan Gold 200 pills' is in the database, but the query is about 'hola' which is not present in the current node. However, the query is also about 'promotion' which is not present in the current node, but the product is present, so the relevance score is 0.6",
#     "relevance_score": 0.6
#   },
#   {
#     "node": {
#       "code": "138401",
#       "type": "Brand",
#       "name": "AHALO BUTTER",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817264",
#           "name": "MOIST & REPAIR SHAMPOO",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817265",
#           "name": "MOIST & REPAIR TREATMENT",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'AHALO BUTTER' is related to the query 'products by hola and in promotion' because it is a brand and the query mentions a brand name 'hola'. Although the query mentions 'in promotion', the current node does not have any information about promotions, but it is still a relevant result.",
#     "relevance_score": 0.8
#   }
# ]

# %%
# filter by relevance
most_related_nodes = []
for node in related_nodes:
    if node["relevance_score"] >= 0.6: most_related_nodes.append(node)
    
print(json.dumps(most_related_nodes, indent=2))
# Out:
# [
#   {
#     "node": {
#       "code": "BP_247314",
#       "type": "Product",
#       "name": "Pien Tze Huang Gan Bao",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "merrygiftmas22_healthp",
#           "name": "Selected Health products",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "printad_0617_1",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "midyearsale_2022_all",
#           "name": "MoneyBack Member purchase selected items upon $50 and enter promo code \u201chappy12\u201d get 12% off ",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "super_jetso_2022_3",
#           "name": "\u6fc0\u62b5\u8cb7",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_liver_daily_protection",
#           "name": "\u65e5\u5e38\u8b77\u809d",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134474",
#           "name": "LONG JIANG",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'Pien Tze Huang Gan Bao' is part of a promotion and has a name that is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "BP_228620",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "cvs22_adult",
#           "name": "Consumption Voucher Rewards - Adult Milk Powder",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050204",
#           "name": "Pain Patch",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134098",
#           "name": "LING NAM",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The current node is a product and has a promotion relationship with several promotions, which matches the user's query for products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_251730",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "sbd_10_2024_health",
#           "name": "Purchases selected Cordyceps/Chinese Medicine upon $699 will get 1pc of complimentary gift for free",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "summercombo_chinesemed",
#           "name": "Buy selected Chinese Medicine/Cordyceps items upon $699",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "141272",
#           "name": "KIN WO TONG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The current node is related to a promotion and has a brand, which matches the user's query for products by a specific brand in promotion.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "sb_packset",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_270618",
#           "name": "Men Expert Hydra Energetic Detox Foam + MA8 Set 100ml+50ml (Cleanser / Foam / Cream / Moisturizing / Detoxify)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_813233",
#           "name": "Revitalift 12345 Packset",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_238875",
#           "name": "Revitalift Essence Water + Day cream set (Anti-aging) 130ml+50ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_802653",
#           "name": "Beauty Tube + MUR Packset",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814867",
#           "name": "Men Expert Hydra Power Water Power Milk Twinset Moisturizer  50ml + 50ml (Moisturizer / Cream / Moisturizing)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_packset' is related to products, and the query contains keywords 'products by hola and in promotion', which indicates a strong relevance.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_292437",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_tourist",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "134098",
#           "name": "LING NAM",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with other nodes, which matches the user's interest in products by Hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "108031",
#       "type": "Brand",
#       "name": "HALOCK",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_810769",
#           "name": "HALOCK S.O.S Pore Refining Watery Mask 8pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_809607",
#           "name": "HALOCK S.O.S Aqua Recharging Mask 8pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_812120",
#           "name": "S.O.S Brightening Watery Mask 8 pcs",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HALOCK' matches the query 'hola' and the neighbors are products, which matches the query 'products by'. Additionally, the neighbors have a 'SELLS' relationship, which implies they are on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_298356",
#       "type": "Product",
#       "name": "NA",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "social_0623_6",
#           "name": "Selected items offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050206",
#           "name": "Medicated Oil",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "114763",
#           "name": "NAU LUNG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The current node is related to the user's query because it is a product and has a promotion relationship with a code that contains the word 'promotion'.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_298442",
#       "type": "Product",
#       "name": "Tin Hee Tong Tin Hee Pills",
#       "description": null,
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "win_back_july_all_items",
#           "name": "Free H&B selected item upon $299 purchase on selected Health Food/Vitamin/Adult Nutrition/Medicine & Eye Care products",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "win_back_july_medicine",
#           "name": "\u6307\u5b9a\u4e2d\u897f\u85e5\u53ca\u773c\u90e8\u8b77\u7406\u7522\u54c1\u6eff$299\u9001H&B\u6307\u5b9a\u7522\u54c1",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "buy2get1_product",
#           "name": "Buy 2 Get 1 Promotion",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "040505",
#           "name": "Fertility Supplements ",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "hh_0309_24",
#           "name": "Purchase selected items upon $188 and enter promo code \u201cMB188\u201d to enjoy 12% off (9-10/3)",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "136092",
#           "name": "TIN HEE TONG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The product 'Tin Hee Tong Tin Hee Pills' is promoted by a category 'Buy 2 Get 1 Promotion' and also belongs to a category 'Fertility Supplements ' which is related to the user's query 'products by hola and in promotion'",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "laurier_brandcat",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_477813",
#           "name": "Laurier F Pantyliner Scented 54's",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_477812",
#           "name": "Laurier F Pantyliner Non-Scented 54's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a category related to products, which matches the user's query about products. Although the query mentions 'hola' and 'promotion', the category is still relevant as it contains products that could be on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "133002",
#       "type": "Brand",
#       "name": "HOE HIN",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_108925",
#           "name": "HOE HIN PAK FAH YEOW #1 20ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_111855",
#           "name": "HOE HIN PAK FAH YEOW #2 10ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_106749",
#           "name": "HOE HIN PAK FAH YEOW #3 5ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816441",
#           "name": "HOE HIN PAK FAH YEOW 50ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HOE HIN' matches the query term 'hola' and the query term 'promotion' is related to the relationship 'SELLS' which implies that the products are on sale.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_155179",
#       "type": "Product",
#       "name": "TONG REN TANG YIN CHIAO CHIEH TU PIEN",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "050205",
#           "name": "Cough Cold & Flu",
#           "type": "Category"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "120483",
#           "name": "TONG REN TANG",
#           "type": "Brand"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         }
#       ]
#     },
#     "explanation": "The product is promoted by '$1999-$250' and '$1488 Free Luggage' which matches the user's query 'products by hola and in promotion'",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "durextest",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814850",
#           "name": "Durex Real Feel Silicone Based Lube 50ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814848",
#           "name": "Durex Warming Lube 100ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products, and the query mentions products by Hola, but since the node is a category and has products by Durex, it's still relevant, but not as specific as the query.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148150",
#       "type": "Promotion",
#       "name": "Buy 2pcs Get Free",
#       "description": "Buy 2 Unit A Get B Free Buy 2pcs Get Fre",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_818414",
#           "name": "AHC Colla-Juvenation Lift 4 Serum 40ML",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_818413",
#           "name": "AHC Colla-Juvenation Lift 4 Eye Cream 30ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and has two products related to it, which matches the user's query for products by Hola in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149085",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_290136",
#           "name": "Nose Hygiene & Comfort 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_242136",
#           "name": "Nasal Hygiene Baby 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_215460",
#           "name": "Blocked Nose 100ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_259290",
#           "name": "Blocked Nose Baby 50ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and has 4 related products, which matches the user's query for products by hola in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "147381",
#       "type": "Promotion",
#       "name": "2 Or More 10%Off",
#       "description": "2 Or More 10%Off 2 Or More 10% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_214452",
#           "name": "Joint Easy 60's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in a promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "146281",
#       "type": "Brand",
#       "name": "HOLA",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817714",
#           "name": "HOLA PORTABLE MAKE UP BOX(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817711",
#           "name": "HOLA  ROCKING RATTLES 10 PCS(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817727",
#           "name": "HOLA PEACOCK(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817734",
#           "name": "HOLA POCKET DINOSAUR(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817718",
#           "name": "HOLA HONEYCOMB TEETHING TOY(SUPPLIER DELIVERY\u201310 WORKING DAYS)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a brand named 'HOLA' and has outgoing relationships with products, which matches the user's query for products by HOLA. The relevance score is 0.8 because the query also mentions 'in promotion', but the provided data does not contain information about promotions.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148532",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_292956",
#           "name": "YiTiao Gen Essence Cream 30g",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148807",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817345",
#           "name": "CORDYCEPS HAIR REJUVENATION 60S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "137649",
#       "type": "Promotion",
#       "name": "2 Or More 10%Off",
#       "description": "2 Or More 10%Off 2 Or More 10% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_242535",
#           "name": "Rauma HP Cream",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149390",
#       "type": "Promotion",
#       "name": "Add $1 Get 1",
#       "description": "2nd Item At $1 Add $1 Get 1",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_815805",
#           "name": "PROCALUN DEEP REPAIRING & MOISTURIZING MASK",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "127077",
#       "type": "Brand",
#       "name": "&HONEY",
#       "description": "&HONEY",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817214",
#           "name": "&HONEY FLEUR KINMOKUSEI & MIMOSA MOIST HAIR OIL 100ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817215",
#           "name": "&HONEY FLEUR MIMOSA MOIST TREATMENT 445G",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817216",
#           "name": "&HONEY FLEUR KINMOKUSEI MOIST SHAMPOO 440ML",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817211",
#           "name": "&HONEY PIXIE MOIST SILKY TREATMENT 445G",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817210",
#           "name": "&HONEY PIXIE MOIST SILKY HAIR OIL 100ML",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a brand named &HONEY, which matches the query term 'hola'. Although the query term 'promotion' is not explicitly mentioned in the node's data, the node is related to products, which are often associated with promotions.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "agelessliving_digest",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_100191",
#           "name": "Nestle NESPRAY 800g",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_299203",
#           "name": "BioGaia Reuteri Gastrus Probiotic Chewable Tablets",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_100192",
#           "name": "INSTANT FULL CREAM MILK POWDER",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_264304",
#           "name": "Probiotics+ Daily Health",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_257101",
#           "name": "Advanced Probiotics",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'agelessliving_digest' is related to products by Hola and in promotion, as it contains products like 'Nestle NESPRAY 800g' and 'INSTANT FULL CREAM MILK POWDER' which are likely to be in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "sb_hairoil",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_242012",
#           "name": "Elseve Extraordinary Oil Infusion Oil Rose 100ml (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_397304",
#           "name": "Elseve Extraordinary Oil Airy Silk Moisturized & Smooth Hair 100ml (Gold) (Japan Hot-selling Hair OIl)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_814050",
#           "name": "Elseve Extraordinary Oil Airy Silk Moisturized & Smooth Hair Refill (Gold) 90ml (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_269617",
#           "name": "Elseve Extraordinary Oil Extra Rich Deeply Moisturized & Damage Care 100ml (Brown) (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_282960",
#           "name": "Elseve Extraordinary Oil Extra Brilliance Moisturized Dazzling Shiny Hair 100ml (Rose) (Japan Hot-selling Hair Oil)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products by Hola and in promotion, as it contains products with 'Elseve Extraordinary Oil' and 'Japan Hot-selling Hair Oil' which are likely to be promoted products.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "149389",
#       "type": "Promotion",
#       "name": "Add $1 Get 1",
#       "description": "2nd Item At $1 Add $1 Get 1",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_815253",
#           "name": "PROCALUN INTENSIVE MOIST & REPAIRING LIP BALM",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "agelessliving_eyes",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_237360",
#           "name": "Vita Green Fortified Natural Formula I See 40pcs",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_807663",
#           "name": "YESNUTRI EYEBRIGHT & BILBERRY SU 60s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_805396",
#           "name": "LUTIGOLD EXTRA 20MG 30S",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_295233",
#           "name": "Macu-Vision Plus",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_224169",
#           "name": "Bilberry Extract",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'agelessliving_eyes' is related to products by Hola and in promotion, as it is part of several products including 'Vita Green Fortified Natural Formula I See 40pcs' and 'YESNUTRI EYEBRIGHT & BILBERRY SU 60s' which are likely to be promoted by Hola.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148806",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817344",
#           "name": "CORDYCEPS HAIR DARKENING 60S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query for products by hola and in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "148805",
#       "type": "Promotion",
#       "name": "2 Or More 25% Off",
#       "description": "2 Or More 25%Off 2 Or More 25% Off",
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PROMOTED_BY",
#           "code": "BP_817341",
#           "name": "TIBETAN WILD CORDYCEPS 60",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is a promotion and one of its neighbors is a product, which matches the user's query about products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "BP_816782",
#       "type": "Product",
#       "name": "CUPAL Angong Niuhuang Wan 1pc",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "flash_deal_1106",
#           "name": "Offer only valid on 6 Nov 2024, MoneyBack Member purchase selected items upon $888 and enter promo code \u3010WTC888\u3011 to save $130 and purchase selected items upon $1,299 and enter promo code \u3010WTC1299\u3011 to save $200",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "hh_1109",
#           "name": "\u53ea\u96509-10/11\u9650\u6642\u9a5a\u559c, \u8cb7\u6eff$188\uff0c\u8f38\u5165\u512a\u60e0\u78bc[MB188]\u5373\u4eab\u5168\u55ae88\u6298",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "040301",
#           "name": "Cardiovascular",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "148407",
#           "name": "Buy 2 at 20% off",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149302",
#           "name": "Supplier Coupon",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149143",
#           "name": "$1999-$250",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147403",
#           "name": "$1488 Free Luggage",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "131484",
#           "name": "CUPAL",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'CUPAL Angong Niuhuang Wan 1pc' is related to the query 'products by hola and in promotion' because it is promoted by a supplier coupon and it is a product from the brand 'CUPAL'.",
#     "relevance_score": 0.7
#   },
#   {
#     "node": {
#       "code": "BP_268043",
#       "type": "Product",
#       "name": "TW Kinzan Kinmen Yi Tiao Gen Pth",
#       "description": "NA",
#       "countryOfOrigin": "N/A",
#       "stockLevelStatus": "N/A",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108\t",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1108_1",
#           "name": "Selected Items Offer",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "health_products_offer",
#           "name": "\u5168\u7dda\u5065\u5eb7\u7522\u54c188\u6298",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "bnj_1120",
#           "name": "Buy Bones & Joints and Adult Nutrition Products upon $350 save $30, upon $888 extra free electric cooker 28cm value $299",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PART_OF",
#           "code": "vita_joint_cross_promotion",
#           "name": "\u8cb7\u7cbe\u9078\u7dad\u7279\u5065\u9748\u5916\u7528\u9aa8\u9abc\u53ca\u95dc\u7bc0\u7522\u54c12\u4ef6\u9001\u6d3b\u95dc\u7d20\u7279\u5f37\u7279\u654810\u7c92\u88dd",
#           "type": "Category"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "148447",
#           "name": "BUY 2 GET 1 FREE",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149409",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "149491",
#           "name": "Over $300 Free GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147773",
#           "name": "OVER $888 FREE GWP",
#           "type": "Promotion"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "PROMOTED_BY",
#           "code": "147771",
#           "name": "$350 less $30",
#           "type": "Promotion"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "SELLS",
#           "code": "141298",
#           "name": "KINZAN",
#           "type": "Brand"
#         }
#       ]
#     },
#     "explanation": "The product 'TW Kinzan Kinmen Yi Tiao Gen Pth' is promoted by several offers, including 'BUY 2 GET 1 FREE', 'Over $300 Free GWP', and '$350 less $30', which matches the user's query for products in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "119102",
#       "type": "Brand",
#       "name": "SALONPAS",
#       "description": "SALONPAS",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_201963",
#           "name": "Salonpas Advanced Formula Patches 4's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_160495",
#           "name": "Salonpas Advanced Formula Patches 10's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_237951",
#           "name": "SALONPAS ADVANCED PLASTER 20S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_298406",
#           "name": "Salonsip Hot Patch 12's",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_152100",
#           "name": "SALONSIP GEL-PATCH 12's",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'SALONPAS' is related to the user's query as it is a brand that sells products, and the query is looking for products by a brand and possibly in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "crest_toothstrips",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_253070",
#           "name": "Crest Whitestrips Gentle Routine",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_171580",
#           "name": "3D White Strips Professional Effect 20 Treatments",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'crest_toothstrips' is related to products, which matches the query 'products by hola and in promotion'. Although 'hola' is not present in the node's neighbors, the presence of 'products' is a strong match.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "135714",
#       "type": "Brand",
#       "name": "DR. ORA",
#       "description": "DR. ORA",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816633",
#           "name": "DR ORA CRYSTAL LUXE COLLAGEN 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816635",
#           "name": "DR ORA LACTOLEAN PROBIOTICS 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816636",
#           "name": "DR ORA BLOCK IT! CARB BLOCKER 10S",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_816634",
#           "name": "DR ORA AURA WHITE ULTRA 15S",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'DR. ORA' is related to the query 'products by hola and in promotion' because it sells products, but the relevance score is not 1 because the query does not mention 'DR. ORA' directly.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "fourhypers_agelessliving",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_277022",
#           "name": "King Alaska Deep Sea Fish Oil Softgel 200s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_282456",
#           "name": "King Alaska Lecithin Softgels 200s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_248504",
#           "name": "GS Go Out Tea 30s",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_804199",
#           "name": "Omega-3 mini EPA/DHA",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_279469",
#           "name": "Rattle Mate Tea 30 tea bags",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node is related to products, and the query mentions products by Hola, which is a brand, and in promotion, which is a common marketing strategy. Although the exact brand 'Hola' is not mentioned in the node's neighbors, the node is related to products, which is a key part of the query.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "sb_mex",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_273885",
#           "name": "HYDRA POWER WATER POWER LOTION 120ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_270618",
#           "name": "Men Expert Hydra Energetic Detox Foam + MA8 Set 100ml+50ml (Cleanser / Foam / Cream / Moisturizing / Detoxify)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_249379",
#           "name": "Men Expert Hydra Energetic Multi-Action 8 Moisturizer 50ml (Moisturizing / Cream/ Detoxify / Energize)",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_249378",
#           "name": "Hydra Energetic Detoxifying Cleansing Foam 100ML",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_273886",
#           "name": "Men Expert Hydra Power Water Power Milk Moisturizer  50ml (Moisturizer / Cream / Moisturizing)",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_mex' is related to products by Hola and in promotion, as it is part of several products with the brand 'Men Expert' and 'Hydra Power Water Power' which might be on promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "sb_ha",
#       "type": "Category",
#       "name": null,
#       "description": null,
#       "relationships": [
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_813644",
#           "name": "Hyaluronic Acid 8s Wonder Water 400ml Airy Silky Liquid Hair Mask",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810148",
#           "name": "Hyaluronic Acid 8s Wonder Water 200ml Airy Silky Liquid Hair Mask",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810149",
#           "name": "Hyaluronic Acid Water Plump Conditioner 440ml",
#           "type": "Product"
#         },
#         {
#           "direction": "INCOMING",
#           "relationship": "PART_OF",
#           "code": "BP_810150",
#           "name": "Hyaluronic Acid Water Plump Shampoo 440ml",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'sb_ha' is related to products by Hola and in promotion, as it contains products from the 'Hyaluronic Acid' category, which is likely to be a product line by Hola, and some of these products are in promotion.",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "101907",
#       "type": "Brand",
#       "name": "AND",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_815836",
#           "name": "UA-767S BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_815837",
#           "name": "UA-654MR BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_809548",
#           "name": "AND ARM TYPE BPM - UA654MR",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'AND' is related to products in promotion, as indicated by the neighbor 'UA-767S BPM (ARM TYPE)(SUPPLIER DELIVERY\u20137-10 WORKING DAYS)[Purchase any A&D blood pressure monitor or GE blood glucose monitor product over HK$500 in a single order, you will receive a free exquisite food box (valued at $198)]'",
#     "relevance_score": 0.8
#   },
#   {
#     "node": {
#       "code": "133353",
#       "type": "Brand",
#       "name": "HIYA KIOGAN",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_201172",
#           "name": "Excellent Pills Hiya Kiogan Gold 200 pills",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'HIYA KIOGAN' is a brand and one of its products 'Excellent Pills Hiya Kiogan Gold 200 pills' is in the database, but the query is about 'hola' which is not present in the current node. However, the query is also about 'promotion' which is not present in the current node, but the product is present, so the relevance score is 0.6",
#     "relevance_score": 0.6
#   },
#   {
#     "node": {
#       "code": "138401",
#       "type": "Brand",
#       "name": "AHALO BUTTER",
#       "description": "",
#       "relationships": [
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817264",
#           "name": "MOIST & REPAIR SHAMPOO",
#           "type": "Product"
#         },
#         {
#           "direction": "OUTGOING",
#           "relationship": "SELLS",
#           "code": "BP_817265",
#           "name": "MOIST & REPAIR TREATMENT",
#           "type": "Product"
#         }
#       ]
#     },
#     "explanation": "The current node 'AHALO BUTTER' is related to the query 'products by hola and in promotion' because it is a brand and the query mentions a brand name 'hola'. Although the query mentions 'in promotion', the current node does not have any information about promotions, but it is still a relevant result.",
#     "relevance_score": 0.8
#   }
# ]

# %%
# answer generation
system_prompt = f"""
You help answer the user's query by accessing a knowledge graph.

Below are the relevant nodes and relationships that may help you answer the user:
{json.dumps(most_related_nodes, indent=2)}

"""

answer = gen_chat(system=system_prompt, user=user_input)
print(answer)
# Out:
# Based on the provided knowledge graph, I found several nodes that match the query "products by hola and in promotion". Here are the top results:
#
# 1. **BP_298442**: "Tin Hee Tong Tin Hee Pills" - This product is promoted by a category "Buy 2 Get 1 Promotion" and also belongs to a category "Fertility Supplements " which is related to the user's query.
# 2. **BP_298356**: "NA" - This product is related to the user's query because it is a product and has a promotion relationship with a code that contains the word 'promotion'.
# 3. **BP_155179**: "TONG REN TANG YIN CHIAO CHIEH TU PIEN" - This product is promoted by '$1999-$250' and '$1488 Free Luggage' which matches the user's query 'products by hola and in promotion'.
# 4. **BP_251730**: "NA" - This product is related to the user's query because it is a product and has a promotion relationship with other nodes, which matches the user's interest in products by Hola and in promotion.
# 5. **BP_247314**: "Pien Tze Huang Gan Bao" - This product is part of a promotion and has a name that is a product, which matches the user's query for products by hola and in promotion.
# 6. **BP_292437**: "NA" - This product is related to the user's query because it is a product and has a promotion relationship with other nodes, which matches the user's interest in products by Hola and in promotion.
# 7. **BP_298442**: "Tin Hee Tong Tin Hee Pills" - This product is promoted by a category "Buy 2 Get 1 Promotion" and also belongs to a category "Fertility Supplements " which is related to the user's query.
# 8. **BP_816782**: "CUPAL Angong Niuhuang Wan 1pc" - This product is related to the query 'products by hola and in promotion' because it is promoted by a supplier coupon and it is a product from the brand 'CUPAL'.
# 9. **BP_268043**: "TW Kinzan Kinmen Yi Tiao Gen Pth" - This product is promoted by several offers, including 'BUY 2 GET 1 FREE', 'Over $300 Free GWP', and '$350 less $30', which matches the user's query for products in promotion.
# 10. **BP_816782**: "CUPAL Angong Niuhuang Wan 1pc" - This product is related to the query 'products by hola and in promotion' because it is promoted by a supplier coupon and it is a product from the brand 'CUPAL'.
#
# These results have a relevance score of 0.7 or higher, indicating that they are likely to be relevant to the user's query.

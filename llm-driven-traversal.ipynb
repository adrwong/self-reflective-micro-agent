# %% [markdown]
# # Self-Reflective Micro-Agent Graph Traversal

# %%
import os
import boto3
import json
import asyncio
from copy import deepcopy
from dotenv import load_dotenv
from neo4j import GraphDatabase, AsyncGraphDatabase
import aioboto3
import nest_asyncio
from typing import Literal, List, Any
from pydantic import BaseModel
from neo4j import AsyncGraphDatabase
from openai import AzureOpenAI, AsyncAzureOpenAI

load_dotenv()
nest_asyncio.apply()
azure_deployment = "gpt-4o-mini" # unused
model_name = "us.meta.llama3-2-11b-instruct-v1:0"
NEO4J_URI = os.getenv("NEO4J_URI", "")
NEO4J_USER = os.getenv("NEO4J_USER", "")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "")
OPENAI_AZURE_API_KEY = os.getenv("OPENAI_AZURE_API_KEY", "")
OPENAI_AZURE_API_VERSION = os.getenv("OPENAI_AZURE_API_VERSION", "")
OPENAI_AZURE_ENDPOINT = os.getenv("OPENAI_AZURE_ENDPOINT", "")

azure_client = AzureOpenAI(
    api_key=OPENAI_AZURE_API_KEY,
    api_version=OPENAI_AZURE_API_VERSION,
    azure_endpoint=OPENAI_AZURE_ENDPOINT
)

async_azure_client = AsyncAzureOpenAI(
    api_key=OPENAI_AZURE_API_KEY,
    api_version=OPENAI_AZURE_API_VERSION,
    azure_endpoint=OPENAI_AZURE_ENDPOINT
)


# user_input = "stomach medicine sold by AS Watson"
# user_input = "medicine for stomach that's in promotion."
# user_input = "any promotion does vitasoy have now?"
user_input = "products by hola and in promotion"
# user_input = "promoted hair products"


# Create an async client for the Bedrock service
async def async_gen_chat(system: str, user: str) -> str:
    session = aioboto3.Session()
    async with session.client(
        "bedrock-runtime",
        aws_access_key_id=os.getenv("AWS_BEDROCK_SA_AK", ""),
        aws_secret_access_key=os.getenv("AWS_BEDROCK_SA_SK", ""),
        region_name=os.getenv("AWS_BEDROCK_META_REGION", "")
    ) as client:
        response = await client.converse(
            modelId=model_name,
            messages=[
                {
                    "role": "user",
                    "content": [{"text": user}]
                }
            ],
            system=[{"text": system}],
            inferenceConfig={
                "maxTokens": 1024,
                "temperature": 0,
                "stopSequences": []
            }
        )
        return response['output']['message']['content'][0]['text']

client = boto3.client(
    "bedrock-runtime",
    aws_access_key_id=os.getenv("AWS_BEDROCK_SA_AK",""),
    aws_secret_access_key=os.getenv("AWS_BEDROCK_SA_SK",""),
    region_name=os.getenv("AWS_BEDROCK_META_REGION","")
)

def gen_chat(system: str, user: str) -> str:
    response = client.converse(
        modelId=model_name,
        messages=[{
            "role": "user",
            "content": [{
                "text": user
            }]
        }],
        system=[{"text": system}],
        inferenceConfig={
            "maxTokens": 1024,
            "temperature": 0,
            "stopSequences": []
        }
    )
    return response['output']['message']['content'][0]['text']

async def async_4o_gen_chat(system: str, user: str) -> str:

    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": user}
    ]
    completion = await async_azure_client.chat.completions.create(
        model=azure_deployment,
        messages=messages,
        temperature=0,
        seed=42
    )
    return completion.choices[0].message.content
    
def g4o_gen_chat(system: str, user: str) -> str:

    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": user}
    ]
    completion = azure_client.chat.completions.create(
        model=azure_deployment,
        messages=messages,
        temperature=0,
        seed=42
    )
    return completion.choices[0].message.content
        

def generate_embedding(input_texts, type: str = "search_document"):
    """
    Generate embeddings using Amazon Bedrock.
    """
    model_id = "cohere.embed-multilingual-v3"
    try:
        # Prepare the payload
        payload = {
            "texts": input_texts,
            "input_type": type,
            "truncate": "START"
        }
        
        # Invoke the model
        response = client.invoke_model(
            modelId=model_id,  # The model ID as configured in Bedrock
            contentType="application/json",  # Content type for the payload
            accept="*/*",  # Accept type for the response
            body=json.dumps(payload)  # Serialize the payload into JSON
        )
        
        # Parse the response
        # print(response['body'].read())
        response_body = json.loads(response['body'].read())
        embedding = response_body.get("embeddings", None)
        
        if embedding is None:
            raise ValueError("No embedding returned in the response.")
        
        return embedding
    
    except Exception as e:
        print(f"Error generating embedding: {e}")
        return None

class Neo4jHelper:

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self._driver.close()

    def create_node_if_not_exists(self, label, code, properties):
        query = f"""
        MERGE (n:{label} {{code: $code}})
        SET
        {', '.join([f'n.{key} = ${key}' for key in properties.keys()])}
        RETURN n
        """
        parameters = {"code": code, **properties}
        
        with self._driver.session() as session:
            result = session.run(query, parameters)
            return result.single()  # Return the first result (the created or matched node)
    
    def run_query(self, query):
        with self._driver.session() as session:
            result = session.run(query)
            return result
    
    def execute_query(self, query, **kwargs):
        records, summary, keys = self._driver.execute_query(
            query,
            **kwargs
        )
        return [record.data() for record in records]

class AsyncNeo4jHelper:

    def __init__(self, uri, user, password):
        # Use the async driver
        self._driver = AsyncGraphDatabase.driver(uri, auth=(user, password))

    async def close(self):
        # Close the driver asynchronously
        await self._driver.close()

    async def create_node_if_not_exists(self, label, code, properties):
        # Use an async session
        query = f"""
        MERGE (n:{label} {{code: $code}})
        SET
        {', '.join([f'n.{key} = ${key}' for key in properties.keys()])}
        RETURN n
        """
        parameters = {"code": code, **properties}
        
        async with self._driver.session() as session:
            # Run the query asynchronously
            result = await session.run(query, parameters)
            # Fetch the first result asynchronously
            return await result.single()  # Return the first result (the created or matched node)

    async def run_query(self, query):
        async with self._driver.session() as session:
            # Run the query asynchronously
            result = await session.run(query)
            return result  # Note: You'll need to process the result asynchronously

    async def execute_query(self, query, **kwargs):
        records, summary, keys = await self._driver.execute_query(
            query,
            **kwargs
        )
        # Process the records asynchronously
        return [record.data() for record in records]

# Connect to Neo4j
neo4j_helper = Neo4jHelper(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
async_neo4j_helper = AsyncNeo4jHelper(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)

# load prompts
with open("prompt_templates/node_reflection.txt", "r") as t: node_reflection_template = t.read()
with open("prompt_templates/explanation_transform.txt", "r") as t: explanation_transform_template = t.read()
with open("prompt_templates/starter.txt", "r") as t: starter_template = t.read()

# %%
def similar_node_by_vector(node_type: Literal["Product", "Brand", "Promotion", "Category"], query: str, threshold: float = 0.7, top_n: int = 3):
    template = """MATCH (p:{node_type}) WITH p,
    vector.similarity.cosine(p.embedding, $embedding) AS score
    WHERE score > {threshold} 
    RETURN labels(p) AS type, p.code AS code, p.title AS title, p.name AS name, p.description AS description, p.elabDescription AS elabDescription, score
    ORDER BY score DESC LIMIT {top_n};"""
    
    result = neo4j_helper.execute_query(
        query=template.format(node_type=node_type, threshold=threshold, top_n=top_n),
        embedding=generate_embedding([query], type="search_query")[0]
    )
    
    return result

# %%
# Kick Starter

starter = json.loads(gen_chat(system=starter_template, user=user_input))
user_input_embedding = generate_embedding([user_input], type="search_query")[0]
all_starts = []
for k, v in starter.items():
    all_possible_starts = similar_node_by_vector(node_type=k, query=", ".join(v))
    # sorted_starts = sorted(all_possible_starts, key=lambda x: x["score"], reverse=True)
    all_starts.extend(all_possible_starts)

# %%
class ReflectiveNode:
    
    class Reflection:
        action: Literal["return", "traverse", "terminate"]
        next_nodes: List['ReflectiveNode'] = []
        explanation: str = ""
        def __init__(self, **kwargs):  self.__dict__.update(kwargs)
    
    class Relationship:
        direction: str
        relationship: str
        node: 'ReflectiveNode'
        
        def __init__(self, **kwargs): self.__dict__.update(kwargs)
        def to_partial_dict(self) -> dict:
            partial_dict = {
                "direction": self.direction,
                "relationship": self.relationship,
                "code": self.node.code,
                "name": self.node.name,
                "type": self.node.type
            }
            # return json.dumps(partial_prompt)
            return partial_dict
        
    code: str
    name: str
    user_query: str
    user_query_embedding: list[float]
    type: Literal["Product", "Category", "Brand", "Promotion"]
    description: str = ""
    relationships: List[Relationship] = []
    previous_node: 'ReflectiveNode' = None
    previous_traversal_reason: str = ""
    n_hop: int = 0
    
    def __init__(self, 
                 code, 
                 name,
                 type, 
                 user_query = "",
                 user_query_embedding = [],
                 description = "",
                 relationships = [],
                 previous_node = None,
                 previous_traversal_reason = "",
                 n_hop = 1,
                 **kwargs):
        self.code = str(code)
        self.name = name
        self.type = type
        self.user_query = user_query
        self.user_query_embedding = user_query_embedding
        self.description = description
        self.previous_node = previous_node
        self.previous_traversal_reason = previous_traversal_reason
        self.n_hop = n_hop
        if relationships: self.relationships = relationships
        self.__dict__.update(kwargs)
    
    def to_partial_dict(self) -> dict:
        partial_dict = {
            "code": self.code,
            "type": self.type,
            "name": self.name,
            "description": self.description
        }
        if self.type == "Product":
            partial_dict["countryOfOrigin"] = getattr(self, "countryOfOrigin", "N/A")
            partial_dict["stockLevelStatus"] = getattr(self, "countryOfOrigin", "N/A")
        return partial_dict
    
    def to_partial_prompt(self) -> str:
        return json.dumps(self.to_partial_dict(), indent=2)
    
    async def set_relationships(self):
        q_code = self.code if self.type == "Promotion" else f"\"{self.code}\""
        # this big query gets all its neighborhoods and filter out the top 5 of each type my similarity to the user's query
        q = f"""
        WITH {self.user_query_embedding} AS queryEmbedding  // Replace with the actual query embedding
        MATCH (n:{self.type} {{code: {q_code}}})
        OPTIONAL MATCH (l)-[r]-(n)
        WHERE l.embedding IS NOT NULL
        WITH l, r, n, vector.similarity.cosine(l.embedding, queryEmbedding) AS similarity
        ORDER BY similarity DESC
        WITH labels(l) AS nodeLabels, l, r, n, similarity
        UNWIND nodeLabels AS nodeLabel
        WITH nodeLabel, l, r, n, similarity
        ORDER BY similarity DESC  // Re-order based on similarity for each label
        WITH nodeLabel, collect({{
            nodeType: nodeLabel,
            code: l.code,
            name: l.name,
            title: l.title,
            description: l.description,
            elabDescription: l.elabDescription,
            countryOfOrigin: l.elabCountryOfOrigin,
            stockLevelStatus: l.stockLevelStatus,
            relationship: r,
            direction: CASE 
                WHEN (n)-[r]->(l) THEN 'OUTGOING' 
                WHEN (n)<-[r]-(l) THEN 'INCOMING' 
                ELSE 'UNDIRECTED' 
            END,
            similarity: similarity
        }}) AS collectedNodes
        WITH nodeLabel, collectedNodes[0..5] AS topNodes
        UNWIND topNodes AS node
        RETURN node.nodeType AS nodeType, node.code AS code, node.name AS name, node.title AS title, node.description AS description, 
            node.elabDescription AS elabDescription, node.countryOfOrigin AS countryOfOrigin, node.stockLevelStatus AS stockLevelStatus, 
            node.relationship AS relationship, node.direction AS direction, node.similarity AS similarity
        """
        db_results = await async_neo4j_helper.execute_query(q)
        self.relationships=[]
        for r in db_results:
            related_node = ReflectiveNode(
                code=r["code"],
                name=r["name"] if r["name"] else r["title"],
                type=r["nodeType"],
                description=r["elabDescription"] if r["elabDescription"] else r["description"],
                user_query=self.user_query,
                user_query_embedding=self.user_query_embedding,
                previous_node=self,
                n_hop=self.n_hop + 1
            )
            if r["countryOfOrigin"]: related_node.countryOfOrigin = r["countryOfOrigin"]
            if r["stockLevelStatus"]: related_node.stockLevelStatus = r["stockLevelStatus"]
            self.relationships.append(self.Relationship(
                direction = r["direction"],
                relationship = r["relationship"][1],
                node = related_node
            ))
            
    def match_node(self, type: str, code: str):
        for r in self.relationships:
            if getattr(r.node, 'type', "") == type and getattr(r.node, 'code', "") == code:
                return r.node
        return None
    
    async def reflect(self) -> Reflection:
        prompt = node_reflection_template
        prompt = prompt.replace("PREVIOUS_NODE", self.previous_node.to_partial_prompt() if self.previous_node else "None")
        prompt = prompt.replace("CURRENT_NODE", self.to_partial_prompt())
        # prompt = prompt.replace("CURRENT_HOP", str(self.n_hop))
        prompt = prompt.replace("CURRENT_RELATIONSHIPS", json.dumps([r.to_partial_dict() for r in self.relationships], indent=2))
        prompt = prompt.replace("REASON_TO_THIS_NODE", f"Hop to this node reason: {self.previous_traversal_reason}" if self.previous_traversal_reason else "")
        gen_result = await async_gen_chat(system=prompt, user=self.user_query)
        gen_result_dict = json.loads(gen_result)
        print(self.previous_traversal_reason)
        print(json.dumps(gen_result_dict, indent=2))
        action = gen_result_dict["action"]
        match action:
            case "return":
                return self.Reflection(action=action, explanation=gen_result_dict.get("explanation", ""))
            case "terminate":
                return self.Reflection(action=action, explanation=gen_result_dict.get("explanation", ""))
            case "traverse":
                next_nodes = []
                for n in gen_result_dict.get("next_nodes", []): next_nodes.append(self.match_node(type=n.get("type", ""), code=n.get("code", "")))
                return self.Reflection(action=action, explanation=gen_result_dict.get("explanation", ""), next_nodes=next_nodes)
            case _:
                return self.Reflection(action="terminate", explanation="")

# %%
# Take the top 5 and create a dict with rank as the key
traversal_beams = {
    rank: {
        "node": ReflectiveNode(
            code=item["code"],
            name=item["name"] if item["name"] else item["title"],
            type=item["type"][0],
            user_query=user_input,
            user_query_embedding=user_input_embedding,
            description=item["description"] if item["description"] else item["elabDescription"]
        ),
        "action": "",
        "next_traversal": {},
        "explanation_for_next_traversal": ""
    }
    for rank, item 
    in enumerate(all_starts, start=1)
}

async def beam_traversal(beam: dict, max_hop: int = 3):
    if not (beam and beam.get("node")): return
    await beam["node"].set_relationships()
    reflection = await beam["node"].reflect()
    beam["explanation_for_next_traversal"] = reflection.explanation
    beam["action"] = reflection.action
    if beam["node"].n_hop == 3: return
    if reflection.action == "traverse":
        beam["next_traversal"] = {
            rank: {
                "node": node,
                "next_traversal": {},
                "action": "",
                "explanation_for_next_traversal": ""
            }
            for rank, node in enumerate(reflection.next_nodes, start=1)
        }
        for rank, next_hop in beam["next_traversal"].items():
            if next_hop.get("node"):
                next_hop["node"].previous_traversal_reason = await async_gen_chat(system=explanation_transform_template, user=reflection.explanation)
                await beam_traversal(beam=next_hop)
        
    return

tasks =[beam_traversal(beam) for rank, beam in traversal_beams.items()]
beam_results = await asyncio.gather(*tasks)
# Out:
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_815253"
#     }
#   ],
#   "explanation": "The current node is a promotion, not a product. To find products by Hola, we need to traverse to the product node."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_242535"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the user is looking for products. We need to traverse to the neighborhood nodes to find the product."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_815805"
#     }
#   ],
#   "explanation": "The current node is a promotion, not a product. To find products by Hola, we need to traverse to the product node."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_817264"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817265"
#     }
#   ],
#   "explanation": "The current node is a brand, so we need to traverse to its products to find the ones that are in promotion."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     },
#     {
#       "type": "Promotion",
#       "code": "147403"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is about products by a brand and in promotion. So, we need to traverse to the promotion nodes."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, so we need to traverse to the brand 'hola' and promotion to find products by 'hola' in promotion"
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_100191"
#     },
#     {
#       "type": "Product",
#       "code": "BP_299203"
#     },
#     {
#       "type": "Product",
#       "code": "BP_100192"
#     },
#     {
#       "type": "Product",
#       "code": "BP_264304"
#     },
#     {
#       "type": "Product",
#       "code": "BP_257101"
#     }
#   ],
#   "explanation": "The current node is a category, so we need to traverse to its neighboring products to find products by Hola and in promotion."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_817714"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817711"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817727"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817734"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817718"
#     }
#   ],
#   "explanation": "The current node is a brand, so we need to traverse to its products to find products by HOLA in promotion."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_817214"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817215"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817216"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817211"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817210"
#     }
#   ],
#   "explanation": "The current node is a brand, so we need to traverse to its neighboring products to find products by &HONEY and in promotion."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149409"
#     },
#     {
#       "type": "Promotion",
#       "code": "149491"
#     },
#     {
#       "type": "Promotion",
#       "code": "147773"
#     },
#     {
#       "type": "Promotion",
#       "code": "147771"
#     },
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola and in promotion. We need to traverse to the promotion nodes to find the relevant information."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149409"
#     },
#     {
#       "type": "Promotion",
#       "code": "149491"
#     },
#     {
#       "type": "Promotion",
#       "code": "147773"
#     },
#     {
#       "type": "Promotion",
#       "code": "147771"
#     },
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola and in promotion. We need to traverse to the promotion nodes to find the relevant information."
# }
#
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_277022"
#     },
#     {
#       "type": "Product",
#       "code": "BP_282456"
#     },
#     {
#       "type": "Product",
#       "code": "BP_248504"
#     },
#     {
#       "type": "Product",
#       "code": "BP_804199"
#     },
#     {
#       "type": "Product",
#       "code": "BP_279469"
#     }
#   ],
#   "explanation": "The current node is a category, so we need to traverse to its neighboring products to find products by Hola and in promotion."
# }
# The previously visited node was a promotion, and the user is searching for products by Hola. Hopped here to find more information about the products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "onedollar_0828"
#     }
#   ],
#   "explanation": "The current node is a product, but the user is searching for products by Hola. The only category related to promotion is 'onedollar_0828'."
# }
# The previously visited node was a promotion, but the user is looking for products. Hopped here to find the neighborhood products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "141251"
#     }
#   ],
#   "explanation": "The current node is a product, but the user is looking for products by a specific brand. The previous node was a promotion, but the user is looking for products by a specific brand. The current node is related to a brand, so we will traverse to the product of that brand."
# }
# The previously visited node was a brand, and the user is looking for products that are in promotion. Hopped here to find the products offered by the brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     },
#     {
#       "type": "Promotion",
#       "code": "148795"
#     },
#     {
#       "type": "Promotion",
#       "code": "102537"
#     },
#     {
#       "type": "Promotion",
#       "code": "147403"
#     }
#   ],
#   "explanation": "The current node is a product by AHALO BUTTER, but it's not in promotion. We need to traverse to promotion nodes to find products by AHALO BUTTER that are in promotion."
# }
# The previously visited node was a promotion, and the user is searching for products by Hola. Hopped here to find more information about the products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "skin_0309_1"
#     },
#     {
#       "type": "Category",
#       "code": "hh_0224_5"
#     },
#     {
#       "type": "Category",
#       "code": "hh_0615_6"
#     },
#     {
#       "type": "Category",
#       "code": "womensday_skin0308"
#     },
#     {
#       "type": "Category",
#       "code": "10thanniversary_skin"
#     },
#     {
#       "type": "Brand",
#       "code": "116902"
#     }
#   ],
#   "explanation": "The current node is a product, but the user is searching for products by Hola. The user is also interested in promotions. We will traverse to the categories and brand to find more information."
# }
# The previously visited node was a brand, and the user is looking for products by HOLA in promotion. Hopped here to find products related to the brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "autumnfss_hola"
#     },
#     {
#       "type": "Category",
#       "code": "24autumnbb_hola"
#     },
#     {
#       "type": "Category",
#       "code": "autumn_fss_all"
#     },
#     {
#       "type": "Category",
#       "code": "flagship_2024_sdd"
#     }
#   ],
#   "explanation": "The current node is a product by HOLA, but it's not in promotion. The user is looking for products by HOLA in promotion, so we need to traverse to the categories related to HOLA to find more products that match the query."
# }
# The previously visited node was a category, and the user is looking for products by Hola and in promotion. Hopped here to find relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "pc_0308_2"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not specify a brand. The user is looking for products by Hola, so we need to traverse to categories to find relevant products."
# }
# The previously visited node was a product, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that are in this promotion."
# }
# The previously visited node was a product, but the query is for products by Hola and in promotion. Hopped here to find the relevant promotion information.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_809470"
#     },
#     {
#       "type": "Product",
#       "code": "BP_815536"
#     },
#     {
#       "type": "Product",
#       "code": "BP_805780"
#     },
#     {
#       "type": "Product",
#       "code": "BP_294790"
#     },
#     {
#       "type": "Product",
#       "code": "BP_189148"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is for products by Hola. We need to traverse to the promoted products to find the relevant information."
# }
# The previously visited node was a brand, and the user is looking for products by &HONEY and in promotion. Hopped here to find neighboring products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "honey_fleur "
#     },
#     {
#       "type": "Product",
#       "code": "honey_fleur_1"
#     },
#     {
#       "type": "Promotion",
#       "code": "149143"
#     },
#     {
#       "type": "Promotion",
#       "code": "148795"
#     },
#     {
#       "type": "Promotion",
#       "code": "147403"
#     }
#   ],
#   "explanation": "The current node does not match the user's query, so we will traverse to its neighboring nodes. We will visit the product nodes that are related to &HONEY and the promotion nodes."
# }
# The previously visited node was a product, but the query is for products by Hola and in promotion. Hopped here to find the relevant promotion information.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_809470"
#     },
#     {
#       "type": "Product",
#       "code": "BP_815536"
#     },
#     {
#       "type": "Product",
#       "code": "BP_805780"
#     },
#     {
#       "type": "Product",
#       "code": "BP_294790"
#     },
#     {
#       "type": "Product",
#       "code": "BP_189148"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is for products by Hola. We need to traverse to the promoted products to find the relevant information."
# }
# The previously visited node was a product, but the user is searching for products by Hola. Hopped here to find more information about the 'onedollar_0828' promotion category.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_810528"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810716"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810713"
#     },
#     {
#       "type": "Product",
#       "code": "BP_284397"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810717"
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola. We need to traverse to the product nodes to find more information."
# }
# The previously visited node was a category, and the user is looking for products by Hola and in promotion. Hopped here to find relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_win_back"
#     },
#     {
#       "type": "Category",
#       "code": "688promotion_0216"
#     },
#     {
#       "type": "Category",
#       "code": "mofusand_estamp_2024"
#     },
#     {
#       "type": "Category",
#       "code": "viphh_0221_24"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not fulfill the user's query for products by Hola and in promotion. We will traverse to the neighboring categories to find relevant products."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola and in promotion. We need to traverse to the brand 'Hola' and promotion to find more information."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. The user is looking for products by HOLA in promotion. Hopped here to find more products by HOLA that match the query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA in promotion, we need to traverse to a promotion node to see if there are any promotions related to HOLA products."
# }
# The previously visited node was a product by AHALO BUTTER, but it's not in promotion. Hopped here to find more information about promotions for AHALO BUTTER products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but it does not provide information about products by AHALO BUTTER. We will traverse to the neighboring product nodes to find the information."
# }
# The previously visited node was a product, but it does not specify a brand. Hopped here to find categories related to products by Hola.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": "pc_0308_2"
#     }
#   ],
#   "explanation": "The current node is a category, but the query is about products by Hola and in promotion. We need to traverse to the brand 'Hola' and the promotion 'pc_0308_2' to find the related products."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that match the query criteria of being by a brand and in this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "114286"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is about products by a brand and in promotion. The current node is by the brand 'NEIPA', but we need to find products by 'hola'. We will traverse to the brand node to find more information about the brand 'hola'."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to explore neighboring categories for potentially relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is for products by Hola and in promotion. We need to explore neighboring brands to find relevant products."
# }
# The previously visited node did not match the user's query, so we will traverse to its neighboring nodes. We will visit the product nodes that are related to &HONEY and the promotion nodes.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, so we will traverse to its neighboring product nodes that are related to 'HOLA'."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_1117"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the promoted products by Hola."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_1117"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the products by Hola."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. The user is looking for products by HOLA in promotion. Hopped here to find more products by HOLA that match the query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA in promotion, we need to traverse to a promotion node to see if there are any products by HOLA in promotion."
# }
# The previously visited node was a product, but it does not specify a brand. The user is looking for products by Hola. Hopped here to find categories that may contain relevant Hola products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not contain products by Hola. We need to traverse to promotions to find products by Hola that are currently on promotion."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that match the query criteria of being by a brand and in this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "108031"
#     }
#   ],
#   "explanation": "The current node is a product by HALOCK, but we need to find products by a brand and in the promotion. We will traverse to the brand node to get more information about the brand."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "hh_"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola and in promotion. We need to traverse to the brand node to find more information about Hola and to the promotion node to find more information about the promotion."
# }
# The previously visited node was a product by AHALO BUTTER, but it's not in promotion. Hopped here to find more information about promotions for AHALO BUTTER products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_109569"
#     },
#     {
#       "type": "Product",
#       "code": "BP_471451"
#     },
#     {
#       "type": "Product",
#       "code": "BP_263605"
#     },
#     {
#       "type": "Product",
#       "code": "BP_471452"
#     },
#     {
#       "type": "Product",
#       "code": "BP_409817"
#     }
#   ],
#   "explanation": "The current node is a promotion, but it does not specify the brand 'AHALO BUTTER'. We need to traverse to the promoted products to find the information about AHALO BUTTER products in promotion."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to explore neighboring categories for potentially relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_471452"
#     },
#     {
#       "type": "Product",
#       "code": "BP_263604"
#     },
#     {
#       "type": "Product",
#       "code": "BP_255583"
#     },
#     {
#       "type": "Product",
#       "code": "BP_238831"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810717"
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is for products. We should traverse to the neighboring products to see if any match the query."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. The user is looking for products by HOLA in promotion. Hopped here to find more products by HOLA that match the query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA in promotion, we need to traverse to a promotion node to see if there are any promotions related to HOLA products."
# }
# The previously visited node was a product, but it does not specify a brand. The user is looking for products by Hola. Hopped here to find categories that may contain relevant Hola products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not contain products by Hola. We need to traverse to promotion nodes to find relevant products."
# }
# The previously visited node did not match the user's query, so we will traverse to its neighboring nodes. We will visit the product nodes that are related to &HONEY to see if they match the query, and also the promotion nodes to see if they provide any relevant information.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_109569"
#     },
#     {
#       "type": "Product",
#       "code": "BP_471451"
#     },
#     {
#       "type": "Product",
#       "code": "BP_263605"
#     },
#     {
#       "type": "Product",
#       "code": "BP_471452"
#     },
#     {
#       "type": "Product",
#       "code": "BP_409817"
#     }
#   ],
#   "explanation": "The current node does not match the user's query, so we will traverse to its neighboring product nodes to see if they match the query."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "hsbc_0718"
#     },
#     {
#       "type": "Category",
#       "code": "20240219_afterholiday"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the products by Hola."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "hsbc_0718"
#     },
#     {
#       "type": "Category",
#       "code": "20240219_afterholiday"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the products by Hola."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "hh_0615_6"
#     },
#     {
#       "type": "Promotion",
#       "code": "hh_0615_6"
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola and in promotion. We need to traverse to the brand and promotion nodes to find more information."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that match the query criteria of being by a brand and in this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "114182"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is about products by a brand and in promotion. The current node is by the brand 'NEPIA', but we need to find products by 'HOLA' and in the promotion '$1999-$250'. We will traverse to the brand node to find more information about the brand 'HOLA'."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to explore neighboring categories that might contain relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     }
#   ],
#   "explanation": "The current node is a category, and the user's query is for products by Hola and in promotion. Since the current node does not match the query, we will traverse to the Brand node 'Hola' to explore its related products."
# }
# The previously visited node was a product by AHALO BUTTER, but it's not in promotion. Hopped here to find more information about promotions for AHALO BUTTER products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_307300"
#     },
#     {
#       "type": "Product",
#       "code": "BP_802014"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809514"
#     },
#     {
#       "type": "Product",
#       "code": "BP_307299"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810577"
#     }
#   ],
#   "explanation": "The current node fulfills the user's query partially, but it does not provide information about AHALO BUTTER products. We need to traverse to the neighboring nodes to find more information about AHALO BUTTER products in promotion."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola and in promotion. We need to traverse to the brand 'Hola' and promotion to find more information."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. The user is looking for products by HOLA in promotion. Hopped here to find more products by HOLA that match the query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_817714"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817711"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817727"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817734"
#     },
#     {
#       "type": "Product",
#       "code": "BP_817718"
#     }
#   ],
#   "explanation": "The current node is a category related to promotion, but it does not directly contain products by HOLA. We need to traverse to the products under this category to find the desired products."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that match the query criteria of being by a brand and in this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "112802"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not match the query criteria of being by a brand. The query is about products by a brand and in promotion, so we need to find the brand node to continue the traversal."
# }
# The previously visited node was a category, and the user is looking for products by Hola and in promotion. Hopped here to find relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_0209_2"
#     },
#     {
#       "type": "Category",
#       "code": "health_1117"
#     },
#     {
#       "type": "Category",
#       "code": "hh_0413_11"
#     },
#     {
#       "type": "Category",
#       "code": "slimming_0531"
#     },
#     {
#       "type": "Category",
#       "code": "hh_88_0913"
#     }
#   ],
#   "explanation": "The current node is a product by BioGaia, not Hola. We need to traverse to categories to find products by Hola and in promotion."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to explore neighboring categories that might contain relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is for products by Hola and in promotion. We need to traverse to the Brand 'Hola' and Promotion nodes to find relevant products."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_pain_relief"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_pain_relief"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node did not match the user's query, so we will traverse to its neighboring nodes. We will visit the product nodes that are related to &HONEY and the promotion nodes.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, so we will traverse to its neighboring product nodes that are related to 'HOLA'."
# }
# The previously visited node was a product by AHALO BUTTER, but it's not in promotion. Hopped here to find more information about promotions for AHALO BUTTER products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but it does not provide information about AHALO BUTTER products. We will traverse to the neighboring product nodes to find more information."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user is searching for products by Hola and in promotion. We need to traverse to the brand 'Hola' and promotion to find more information."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Now, we need to find products that match the query criteria of being by a brand and in this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "115887"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not match the query criteria of being by a brand. The query is about products by a brand and in promotion, so we need to find the brand of the product to proceed."
# }
# The previously visited node was a category, and the user is looking for products by Hola and in promotion. Hopped here to find relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "fourhypers_agelessliving"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not fulfill the user's query for products by Hola and in promotion. The next step is to traverse to the category node that the current product belongs to."
# }
# The previously visited node was a product by BioGaia, not Hola. Hopped here to find products by Hola.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": "health_0209_2"
#     }
#   ],
#   "explanation": "The current node is a category, not a brand or a promotion. We need to traverse to the brand 'Hola' and the promotion 'Selected items offer' to find products by Hola and in promotion."
# }
# The previously visited node was a brand, and the user is looking for products by HOLA in promotion. Hopped here to find products related to the brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "autumnfss_hola"
#     },
#     {
#       "type": "Category",
#       "code": "24autumnbb_hola"
#     },
#     {
#       "type": "Category",
#       "code": "060701"
#     },
#     {
#       "type": "Category",
#       "code": "autumn_fss_all"
#     },
#     {
#       "type": "Category",
#       "code": "flagship_2024_sdd"
#     }
#   ],
#   "explanation": "The current node is a product by HOLA, but it's not in promotion. We need to traverse to the categories related to HOLA to find products that are in promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_offer"
#     },
#     {
#       "type": "Category",
#       "code": "health_offer2"
#     },
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_social_0223_7"
#     },
#     {
#       "type": "Category",
#       "code": "health_0301_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories to find the products by Hola."
# }
# The previously visited node was a brand, and the user is looking for products by &HONEY and in promotion. Hopped here to find neighboring products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "viphh_1129"
#     },
#     {
#       "type": "Product",
#       "code": "flash_deal_1212"
#     },
#     {
#       "type": "Product",
#       "code": "hh_1123"
#     },
#     {
#       "type": "Product",
#       "code": "flash_deal_1204"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not fulfill the user's query. The user is looking for products by &HONEY, but the current product is by &HONEY FLEUR MIMOSA MOIST TREATMENT 445G. We will traverse to neighboring products to find the one that matches the query."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_offer"
#     },
#     {
#       "type": "Category",
#       "code": "health_offer2"
#     },
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_social_0223_7"
#     },
#     {
#       "type": "Category",
#       "code": "health_0301_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a brand, and the user is looking for products that are in promotion. Hopped here to find the products offered by the brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     },
#     {
#       "type": "Promotion",
#       "code": "148795"
#     },
#     {
#       "type": "Promotion",
#       "code": "102537"
#     },
#     {
#       "type": "Promotion",
#       "code": "147403"
#     }
#   ],
#   "explanation": "The current node is a product by AHALO BUTTER, but it's not in promotion. We need to traverse to promotion nodes to find products by AHALO BUTTER that are in promotion."
# }
# The previously visited node was a product, but the user is searching for products by Hola. The user is also interested in promotions. Hopped here to find more information about the categories and brand.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": null
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a brand, but the user is searching for products by Hola and in promotion. We need to traverse to categories and promotions to find more information."
# }
# The previously visited node was a product by BioGaia, not Hola. Hopped here to find products by Hola.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": "health_1117"
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is about products by Hola and in promotion. We need to traverse to the Brand node 'Hola' and the Promotion node related to the current category 'Selected items offer'."
# }
# The previously visited node was a product that does not fulfill the user's query for products by Hola and in promotion. Hopped here to find a broader category that might contain the desired product.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find a broader category that might contain the desired product, we need to traverse to the Brand 'Hola' and Promotion nodes."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to find categories related to HOLA that may have products in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category related to HOLA, but it's not a product. To find products by HOLA that are in promotion, we need to traverse to the promotion node to see if there are any related products."
# }
# The previously visited node was a product, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Since the query is about products, we need to traverse to the neighboring products."
# }
# The previously visited node was a brand, and the user is looking for products by &HONEY and in promotion. Hopped here to find neighboring products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "honey_fleur "
#     },
#     {
#       "type": "Category",
#       "code": "honey_fleur_1"
#     }
#   ],
#   "explanation": "The current node is a product by &HONEY, but the user is looking for products by &HONEY and in promotion. The current node is not in promotion, so we need to traverse to its neighboring categories to find products that are in promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1120"
#     },
#     {
#       "type": "Category",
#       "code": "sbd_10_2024_health"
#     },
#     {
#       "type": "Category",
#       "code": "summercombo_chinesemed"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories to find the promoted products by Hola."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1120"
#     },
#     {
#       "type": "Category",
#       "code": "sbd_10_2024_health"
#     },
#     {
#       "type": "Category",
#       "code": "summercombo_chinesemed"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a category, and the user is looking for products by Hola and in promotion. Hopped here to find relevant products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "040303"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not match the user's query for products by Hola and in promotion. The next step is to traverse to a category node to find relevant products."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to find categories related to HOLA that may have products in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category related to HOLA, but it's not a product in promotion. To find products by HOLA that are in promotion, we need to traverse to the promotion node to see if there are any related products."
# }
# The previously visited node was a product by BioGaia, not Hola. Hopped here to find products by Hola.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Brand",
#       "code": "Hola"
#     },
#     {
#       "type": "Promotion",
#       "code": "hh_0413_11"
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is about products by Hola and in promotion. We need to traverse to the Brand node 'Hola' and the Promotion node 'hh_0413_11' to find the relevant products."
# }
# The previously visited node was a product by AHALO BUTTER, but it's not in promotion. Hopped here to find more information about promotions for AHALO BUTTER products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but it does not specify the product is by AHALO BUTTER. We need to traverse to the neighboring product nodes to find the information."
# }
# The previously visited node was a promotion, but the query is about products by a brand and in promotion. Hopped here to find more information about the promotion. Since the query is about products, we need to traverse to the neighboring products to find relevant products by the brand that are in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "114286"
#     }
#   ],
# ...
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the products by Hola."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to find relevant categories that may contain products matching the user's query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "hhedm_0810_6"
#     }
#   ],
#   "explanation": "The current node is a category, but it does not directly match the user's query. We need to traverse to find relevant categories that may contain products matching the user's query."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "hsbc_0718"
#     },
#     {
#       "type": "Category",
#       "code": "20240219_afterholiday"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     },
#     {
#       "type": "Category",
#       "code": "senior_citizen_wed"
#     },
#     {
#       "type": "Brand",
#       "code": "101397"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. We need to traverse to the categories and brand to find the products by Hola."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to explore neighboring categories for products by HOLA that are currently in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA that are currently in promotion, we need to traverse to the promotion node to see if there are any related promotions."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to find relevant categories that may contain products matching the user's query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "BP_257101"
#     }
#   ],
#   "explanation": "The current node does not match the user's query, so we need to traverse to a neighboring node. Since the previous node was a product, we can try to find a category that may contain products matching the user's query."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_pain_relief"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to explore neighboring categories for products by HOLA that are currently in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA that are currently in promotion, we need to traverse to the Promotion node to see if there are any promotions related to HOLA products."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_pain_relief"
#     },
#     {
#       "type": "Category",
#       "code": "healthexpo23_vg_selected"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108"
#     },
#     {
#       "type": "Category",
#       "code": "bnj_1108_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a product that does not match the user's query for products by Hola and in promotion. Hopped here to find relevant categories that may contain products matching the user's query.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "BP_257101"
#     }
#   ],
#   "explanation": "The current node is a promotion, but it does not match the user's query for products by Hola and in promotion. We need to traverse to a category that may contain products matching the user's query."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to explore neighboring categories for products by HOLA that are currently in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but the user's query is about products by HOLA that are in promotion. We need to traverse to the promotion node to find the products that match the query."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_offer"
#     },
#     {
#       "type": "Category",
#       "code": "health_offer2"
#     },
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_social_0223_7"
#     },
#     {
#       "type": "Category",
#       "code": "health_0301_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Category",
#       "code": "health_offer"
#     },
#     {
#       "type": "Category",
#       "code": "health_offer2"
#     },
#     {
#       "type": "Category",
#       "code": "social_0623_6"
#     },
#     {
#       "type": "Category",
#       "code": "health_social_0223_7"
#     },
#     {
#       "type": "Category",
#       "code": "health_0301_1"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The current node is not related to the user's query, so we need to traverse to its neighborhood nodes."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to explore neighboring categories for products by HOLA that are currently in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it does not fulfill the user's query. To find products by HOLA that are in promotion, we need to traverse to the Promotion node to see if there are any promotions related to HOLA products."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "116478"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The next step is to traverse to the product node that is related to Hola."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the promoted products.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "116478"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the promoted products. The next step is to traverse to the product node that is related to Hola."
# }
# The previously visited node was a product by HOLA, but it's not in promotion. Hopped here to explore neighboring categories for products by HOLA that are currently in promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": null
#     }
#   ],
#   "explanation": "The current node is a category, but it's not a promotion. To find products by HOLA that are in promotion, we need to traverse to a promotion node."
# }
# The previously visited node was a product, but the query is for products by Hola and in promotion. Hopped here to find the relevant promotion information.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is for products by Hola. We need to traverse to the products that are promoted by this promotion."
# }
# The previously visited node was a product, but the query is for products by Hola and in promotion. Hopped here to find the relevant promotion information.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_393548"
#     },
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     },
#     {
#       "type": "Product",
#       "code": "BP_809401"
#     },
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     },
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a promotion, but the query is for products by Hola. We need to traverse to the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola in promotion. The current node is promoted by the previously visited promotion, so we need to traverse to the promotion to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola in promotion. The current node is promoted by the promotion, but the promotion is not related to Hola. We need to traverse to the promotion to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not fulfill the user's query. The query is for products by Hola and in promotion. The current node is promoted by a promotion, so we need to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_810769"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not fulfill the user's query. The query is for products by Hola and in promotion. The current node is promoted by a promotion, so we need to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. The current node is promoted by the previously visited node, so we need to traverse to the promotion node to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Promotion",
#       "code": "149143"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. The current node is promoted by the previously visited node, so we need to traverse to the promotion node to find the products that are promoted by this promotion."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion. Since the query is for products by Hola, we need to traverse to other nodes to find the relevant products."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_218463"
#     }
#   ],
#   "explanation": "The current node is a product, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion. Since the query is for products by Hola, we need to traverse to other nodes to find the relevant products."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not contain 'Hola' in its name. We need to traverse to other nodes to find the products that are promoted by the previous promotion and contain 'Hola' in their name."
# }
# The previously visited node was a promotion, but the query is for products by Hola. Hopped here to find the products that are promoted by this promotion.
# {
#   "action": "traverse",
#   "next_nodes": [
#     {
#       "type": "Product",
#       "code": "BP_813756"
#     }
#   ],
#   "explanation": "The current node is a product, but it does not contain 'Hola' in its name. We need to traverse to other nodes to find the products that are promoted by the previous promotion and contain 'Hola' in their name."
# }

# %%
returned_nodes = []

def format_all_beams(beam: dict):
    if beam["node"]:
        beam["relationships"] = [r.to_partial_dict() for r in beam["node"].relationships ]
        beam["node"] = beam["node"].to_partial_dict()
        if beam.get("action", "") == "return": returned_nodes.append(beam)
        else:
            for next_rank, next_hop in beam["next_traversal"].items():
                format_all_beams(next_hop)
        
formatted_result = deepcopy(traversal_beams)
for rank, main_beam in formatted_result.items():
    format_all_beams(main_beam)

# %%
# answer generation
system_prompt = f"""
You help answer the user's query by accessing a knowledge graph.

Below are the relevant nodes and relationships that may help you answer the user:
{json.dumps(returned_nodes, indent=2)}

"""

answer = gen_chat(system=system_prompt, user=user_input)
print(await answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       2 system_prompt = f"""
#       3 You help answer the user's query by accessing a knowledge graph.
#       4
#    (...)
#       7
#       8 """
#      10 answer = gen_chat(system=system_prompt, user=user_input)
# ---> 11 print(await answer)
#
# TypeError: object str can't be used in 'await' expression
